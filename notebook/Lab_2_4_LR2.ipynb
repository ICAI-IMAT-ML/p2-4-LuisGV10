# %% [markdown]
# # Laboratory 2.4: Linear Regression contd.
#
# In this practice you will extend your Linear Regression code to a more general case. Here you will need the `synthetic_dataset.csv` present in the .zip file you downloaded alongside this notebook.
#
# In addition, we will be using the following libraries:
# - Data management:
#     - [numpy](https://numpy.org/)
#     - [pandas](https://pandas.pydata.org/)
#     - [scipy](https://scipy.org/)
# - Modelling:
#     - [scikit-learn](https://scikit-learn.org)
# - Plotting:
#     - [seaborn](https://seaborn.pydata.org/)
#     - [matplotlib](https://matplotlib.org/)
#
# ### **All the things you need to do are marked by a "TODO" comment nearby. Make sure you *read carefully everything before working* and solve each point before submitting your solution.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import os
import sys
# Get the absolute path of the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add it to sys.path
sys.path.insert(0, project_root)

# %% [markdown]
# ### Custom Linear Regression model

# %% [markdown]
# You are going to be working with the following class that you already know from the previous practice, so feel free to recycle as much code as you want (or can). In this case, you will be enhancing its functionalities, getting a more general function than the one you implemented before.
#
# **For now, just continue with the practice and do not fill anything, you will come back later to fill the gaps.**

# %%
from src.Lab_2_4_LR2 import LinearRegressor

# %% [markdown]
# **Data**: Remember, from the previous lab session, we had the following univariate dataset:

# %%
# Define data to use in this practice
x = np.array([0, 3, 2, 1, 4, 6, 7, 8, 9, 10])
y = np.array([2, 3, 2, 4, 5, 7, 9, 9, 10, 13])

# %% [markdown]
# Use the code *you wrote* from the previous practice (not the sklearn version) to fit the data in the following cell

# %%
linreg = LinearRegressor()
linreg.fit(x, y)

# %% [markdown]
# Before we get into the things you'll do today, let's construct a function that provides the values for the $R^2$, RMSE and MAE. For this, the inputs of this function are the true $y$ values and the predicted $\hat{y}$ values

# %%
from src.Lab_2_4_LR2 import evaluate_regression

# %%
# Obtain regression performance metrics
y_pred = linreg.predict(x)
evaluation_metrics = evaluate_regression(y, y_pred)
print(evaluation_metrics)
# Out:
# {'R2': 0.9201359388275276, 'RMSE': 1.0126472956832233, 'MAE': 0.8945454545454552}

# %% [markdown]
# ## Polynomial regression

# %% [markdown]
# In the previous practice, you have trained a model assuming that the relationship between input and output is linear. However, in most real cases this is not common and the relationship between input and output is not linear. In this section, we are going to learn how to deal with non-linear relationships when using linear models. Read `synthetic_dataset.csv` and train a linear regression model.
#
# *The target variable is the last column of the dataset*

# %%
data = pd.read_csv(f"{project_root}/data/synthetic_dataset.csv")

X = np.array(data[["Input1", "Input2", "Input3"]])
y = np.array(data["Output"])

# %% [markdown]
# In this case we will skip the preprocessing and go straight to the modelling phase. Therefore, fit the model here.

# %%
linreg.fit(X, y, "gradient_descent")
y_pred = linreg.predict(X)
# Out:
# Epoch 0: MSE = [0.00459515 0.00088309 0.00499969 ... 0.00310517 0.00147593 0.00037857]

# %%
evaluate_regression(y, y_pred)
# Out:
# {'R2': 0.12086190499422456,
#  'RMSE': 4.44062273545173,
#  'MAE': 3.3713233918246917}

# %% [markdown]
# If you trained the model well, the $R^2$ metric will be terrible, in the order of $0.5$. **What happened here?** Let's try to clear this via the *study of the residuals*.
#
# Create a function to plot the residuals of the model. This function shall:
# - Create a **histogram** of the residuals.
# - Create a **Q-Q plot** of the residuals.
# - Create a **scatterplot of the residuals against each input variable, the true output variable and the predictions**.
#
# **Why do we want to check the residuals this way?**
#
# > Write your answer here

# %%
def plot_residuals(data, output_column, prediction_column):
    """
    Plot residuals of a model against all variables in the DataFrame, using box plots for
    categorical variables and scatter plots for continuous variables. Additionally, plot
    a histogram and a QQ-plot of the residuals.

    Args:
        data (pd.DataFrame): The DataFrame containing the data.
        output_column (str): The name of the output column.
        prediction_column (str): The name of the prediction column.
    """
    residuals = data[output_column] - data[prediction_column]
    
    num_features = len(data.columns) - 2  # Exclude output and prediction columns

    # Determine the number of rows and columns for subplots
    num_rows = int(np.ceil(np.sqrt(num_features + 4)))  # Add 4 for histogram, Q-Q plot, true output vs residuals, and predictions vs residuals
    num_cols = int(np.ceil((num_features + 4) / num_rows))

    # Plot histogram of residuals
    plt.figure(figsize=(5 * num_cols, 4 * num_rows))
    plt.subplot(num_rows, num_cols, 1)
    plt.hist(residuals, bins=30, edgecolor='black')
    plt.title('Histogram of Residuals')
    plt.xlabel('Residuals')
    plt.ylabel('Frequency')

    plt.subplot(num_rows, num_cols, 2)
    stats.probplot(residuals, dist="norm", plot=plt)      
    plt.title('Q-Q Plot of Residuals')

    plt.subplot(num_rows, num_cols, 3)
    plt.scatter(data[output_column], residuals, alpha=0.5)     
    plt.title('Residuals vs True Output')
    plt.xlabel('True Output')
    plt.ylabel('Residuals')

    # Plot residuals against prediction variable
    plt.subplot(num_rows, num_cols, 4)
    plt.scatter(data[prediction_column], residuals, alpha=0.5)   # Use this as example for later
    plt.title('Residuals vs Predictions')
    plt.xlabel('Predictions')
    plt.ylabel('Residuals')

    for i, col in enumerate(data.columns):
        if col not in [output_column, prediction_column]:
            plt.subplot(num_rows, num_cols, i + 5)
            plt.scatter(data[col], residuals, alpha=0.5)  
            plt.title(f'Residuals vs {col}')
            plt.xlabel(col)
            plt.ylabel('Residuals')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Now, **print the coefficients** of the model **alongside the plots** you can generate with the previous function

# %%
coef_dict = {'Input' + str(i+1): coef for i, coef in enumerate(linreg.coefficients)}
print(f"Coefficients of the model: {coef_dict}")  

# Plot the residuals for the predictions
data["Predictions"] = linreg.predict(X)
plot_residuals(data, 'Output', 'Predictions')
# Out:
# Coefficients of the model: {'Input1': 0.0027673853888358674, 'Input2': 0.04783835105239394, 'Input3': 1.6499435848958555}

# %% [markdown]
# **What are we seeing here? Is there any way to improve the model?**
# > Write your answer here

# %% [markdown]
# As you may expect, you should see some higher-order contribution to the behavior of the data, since some of the residuals have clear structures. In particular, `Input1` has a higher-order polynomial contribution (*which order do you think?*), while `Input2` has an *exponential* form.
#
# In order to fit a regression model with these contributions, construct a new dataframe where each column corresponds to the desired manipulation of each variable. Then, fit the regression model and see the results.
#
# * Also, pay attention to the fact that you can use whatever contribution you see fit here, not just these previous ones.

# %%
data_transf = pd.DataFrame({'Input1': data["Input1"] ** 2,   # Substitute "None" by the degree you think works here
                            'Input2': np.exp(data["Input3"]),
                            'Input3': data["Input4"],
                            'Output': data["Output"]})
X_transf = data_transf.iloc[:,:3].values

# Train linear regression model
linreg = LinearRegressor()
linreg.fit(X_transf, y)

# Evaluate the metrics to see the behavior
y_pred = linreg.predict(X_transf)
evaluation_metrics = evaluate_regression(y, y_pred)
print(evaluation_metrics)
# Out:
# {'R2': 0.9557524745534756, 'RMSE': 0.9962304737909358, 'MAE': 0.7956340344398113}

# %% [markdown]
# Now, print again the coefficients for the model and plot the residuals as you did before.
#
# **What do you observe?**
# > Write your answer here

# %%
coef_dict = {'Input' + str(i+1): coef for i, coef in enumerate(linreg.coefficients)}
print(f"Coefficients of the model: {coef_dict}")
data_transf["Predictions"] = linreg.predict(X_transf)
plot_residuals(data_transf, 'Output', 'Predictions')
# Out:
# Coefficients of the model: {'Input1': 1.9985407741302759, 'Input2': 0.9951259300218519, 'Input3': 2.988069929362549}

# %% [markdown]
# ## Categorical variables

# %% [markdown]
# Linear regression, as is, can not deal with categorical variables. Therefore, we need to encode the variables when preprocessing the data. Complete the one-hot-encode function below. Take into account that strings shall be treated automatically as categorical variables.
# <center>
#
# ![Image](https://miro.medium.com/v2/resize:fit:1358/1*ggtP4a5YaRx6l09KQaYOnw.png)
#
# </center>

# %%
from src.Lab_2_4_LR2 import one_hot_encode

# %% [markdown]
# We will use this in a usual dataset from the internet. If everything is well, you should be able to run the following code as-is.

# %%
# Load the dataset
url = "https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv"
data = pd.read_csv(url)


y = data['charges'].values
X = data.drop(columns=['charges']).values

# Preprocess the data
# Identify categorical columns for one-hot encoding
categorical_columns = [data.columns.get_loc(col) for col in ['sex', 'smoker', 'region']]

# One-hot encode categorical variables
X_encoded = one_hot_encode(X, categorical_columns, drop_first=True)
X_encoded = X_encoded.astype(float)                                  # Watch out for this!

# Instantiate and fit the LinearRegressor
model = LinearRegressor()
model.fit(X_encoded, y)

# Predict and evaluate
y_pred = model.predict(X_encoded)
evaluation_metrics = evaluate_regression(y, y_pred)
print(evaluation_metrics)
# Out:
# {'R2': 0.7509130345985207, 'RMSE': 6041.6796511744515, 'MAE': 4170.886894163565}

# %% [markdown]
# Compare yourself with scikit

# %%
from sklearn.linear_model import LinearRegression

# Load the dataset
url = "https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv"
data = pd.read_csv(url)

# Preprocess the data
data_encoded = pd.get_dummies(data) 

# Split the data into features (X) and target (y)
X = data_encoded.drop('charges', axis=1)
y = data_encoded['charges']

# Instantiate the LinearRegression model
model = LinearRegression()

# Fit the model on the training data
model.fit(X, y)

# Make predictions on the test data
y_pred = model.predict(X)

# Evaluate the model
evaluation_metrics = evaluate_regression(y, y_pred)
print(evaluation_metrics)
# Out:
# {'R2': 0.7509130345985207, 'RMSE': 6041.6796511744515, 'MAE': 4170.886894163589}

# %% [markdown]
# ### Colored residuals

# %% [markdown]
# Now that we have categorical variables, the relationship between inputs and outputs might differ for different levels of the categorical variables. Therefore, you will modify the `plot_residuals` function to **color the scatter plots based on the value of a specific categorical variable**.

# %%
def plot_residuals(data, output_column, prediction_column, categorical_var=None):
    """
    Plot residuals of a model against all variables in the DataFrame. Additionally, plot
    a histogram and a QQ-plot of the residuals.

    Args:
        data (pd.DataFrame): The DataFrame containing the data.
        output_column (str): The name of the output column.
        prediction_column (str): The name of the prediction column.
        categorical_var (str, optional): The name of a categorical variable for coloring. Defaults to None.
    """
    data['residuals'] = data[output_column] - data[prediction_column]

    # Identify columns to plot (excluding the output and prediction columns)
    columns_to_plot = [col for col in data.columns if col not in [output_column, prediction_column, 'residuals']]

    # Number of rows and columns for the subplot
    n_cols = 3
    n_rows = int(len(columns_to_plot) / n_cols) + 2  # Additional row for histogram and QQ-plot

    # Create subplots
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 5))

    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    for i, col in enumerate(columns_to_plot):
        ax = axes[i]
        
        if categorical_var and categorical_var in data.columns:
            sns.scatterplot(x = data[col], y = data[output_column], data=data, ax=ax, hue = data[categorical_var])
        else:
            sns.scatterplot(x = data[col], y = data[output_column], data=data, ax=ax)
        
        ax.set_title(f'Residuals vs {col}')
        ax.axhline(0, ls='--', color='r')

    # Histogram of residuals
    sns.histplot(data['residuals'], kde=True, ax=axes[i + 1])
    axes[i + 1].set_title('Histogram of Residuals')

    # QQ-plot of residuals
    stats.probplot(data['residuals'], dist="norm", plot=axes[i + 2])
    axes[i + 2].set_title('QQ-Plot of Residuals')

    # Hide any unused axes
    for j in range(i + 3, len(axes)):
        axes[j].set_visible(False)

    plt.tight_layout()
    plt.show()

data['predictions'] = model.predict(X)
# Example usage
plot_residuals(data, 'charges', 'predictions', 'smoker')

# %% [markdown]
# **What's happening with the residuals?**
# > Write your answer here

# %% [markdown]
# # _Rolling in the deep_

# %% [markdown]
# Following the theory taught in class, do the following:
#
# 1. **implement the gradient descent algorithm** to train the linear regression model and reproduce the results using this training method. You can find the structure for the gradient descent inside the initial linear regression function, inside the method `fit_gradient_descent`.
# 2. As final steps, **display the progress of the loss function by plotting the gradient descent steps on the X-axis and the loss function on the Y-axis for each step**.
# 3. Additionally, **using the same representation as in the previous section where each axis represents the values of w and b, show the sequence of steps that bring you closer to the optimum each time**. Each step should be a point in space, with coordinates (w,b). Compare all the results with the optimal solution from the scikit fit coefficients.
#
# Feel free to add as many cells as you may need from here onwards in order to fulfill these three tasks

# %%
linreg_m = LinearRegressor()

mae = []
intercept_m = []
coefficients_m = []
for i in range(1, 10**3 + 1):
    linreg_m.fit(X_encoded, y, method="gradient_descent", learning_rate=0.0001, iterations=i)
    y_pred_m = linreg_m.predict(X_encoded)
    evaluation_metrics_m = evaluate_regression(y, y_pred_m)
    mae.append(evaluation_metrics_m["MAE"])
    intercept_m.append(linreg_m.intercept)
    coefficients_m.append(linreg_m.coefficients)

print(evaluation_metrics_m)
# Out:
# Epoch 0: MSE = 0       213072.066687
# 1         2224.488144
# 2        14793.891232
# 3       361212.140504
# 4        11173.125029
#             ...
# 1333     83976.898343
# 1334      3635.999975
# 1335      1984.468917
# 1336      3012.442903
# 1337    634669.558220
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.255231
# 1         2224.407670
# 2        14793.561283
# 3       361209.848166
# 4        11172.742421
#             ...
# 1333     83975.319693
# 1334      3635.894340
# 1335      1984.388867
# 1336      3012.342106
# 1337    634663.749215
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.899400
# 1         2224.913054
# 2        14794.980538
# 3       361217.169987
# 4        11174.152612
#             ...
# 1333     83979.993465
# 1334      3636.546633
# 1335      1984.924635
# 1336      3012.887790
# 1337    634679.478959
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.240063
# 1         2224.544907
# 2        14794.366123
# 3       361215.940395
# 4        11173.692848
#             ...
# 1333     83979.759118
# 1334      3636.085533
# 1335      1984.501990
# 1336      3012.620512
# 1337    634679.970835
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.617407
# 1         2224.269451
# 2        14793.401366
# 3       361211.385730
# 4        11172.876542
#             ...
# 1333     83976.390323
# 1334      3635.756956
# 1335      1984.246131
# 1336      3012.303430
# 1337    634669.289993
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.066219
# 1         2224.171864
# 2        14792.958678
# 3       361207.865932
# 4        11172.287608
#             ...
# 1333     83973.947530
# 1334      3635.588292
# 1335      1984.137729
# 1336      3012.096984
# 1337    634660.365899
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.433270
# 1         2224.595510
# 2        14794.463547
# 3       361216.149744
# 4        11173.761773
#             ...
# 1333     83979.849624
# 1334      3636.159232
# 1335      1984.558194
# 1336      3012.648265
# 1337    634679.760679
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.422798
# 1         2224.187847
# 2        14792.955795
# 3       361208.078882
# 4        11172.348662
#             ...
# 1333     83973.977028
# 1334      3635.634568
# 1335      1984.164722
# 1336      3012.146875
# 1337    634660.371777
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.351106
# 1         2224.076731
# 2        14792.508574
# 3       361205.674076
# 4        11171.922235
#             ...
# 1333     83972.103651
# 1334      3635.480077
# 1335      1984.061442
# 1336      3011.984641
# 1337    634654.723096
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.121981
# 1         2225.021227
# 2        14795.416669
# 3       361219.678922
# 4        11174.584154
#             ...
# 1333     83981.840687
# 1334      3636.688303
# 1335      1985.016187
# 1336      3013.043682
# 1337    634685.251910
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.214463
# 1         2224.747093
# 2        14794.308400
# 3       361213.093589
# 4        11173.454343
#             ...
# 1333     83977.026249
# 1334      3636.324059
# 1335      1984.751809
# 1336      3012.658271
# 1337    634669.366309
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.853377
# 1         2225.018529
# 2        14795.532090
# 3       361220.333393
# 4        11174.657641
#             ...
# 1333     83982.492084
# 1334      3636.655716
# 1335      1984.994734
# 1336      3013.037040
# 1337    634687.164029
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.888148
# 1         2224.902037
# 2        14795.214853
# 3       361219.215865
# 4        11174.422654
#             ...
# 1333     83981.711831
# 1334      3636.521827
# 1335      1984.869964
# 1336      3012.914084
# 1337    634685.005149
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.550423
# 1         2224.396183
# 2        14793.609781
# 3       361211.487328
# 4        11172.977920
#             ...
# 1333     83976.277636
# 1334      3635.900788
# 1335      1984.371207
# 1336      3012.381056
# 1337    634668.048868
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.829484
# 1         2225.017442
# 2        14795.351217
# 3       361218.660275
# 4        11174.421111
#             ...
# 1333     83981.170921
# 1334      3636.669893
# 1335      1985.020337
# 1336      3013.005576
# 1337    634683.011045
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.065587
# 1         2224.699107
# 2        14794.560522
# 3       361215.565977
# 4        11173.760583
#             ...
# 1333     83979.269236
# 1334      3636.272751
# 1335      1984.676801
# 1336      3012.692050
# 1337    634677.183637
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.710354
# 1         2224.252039
# 2        14792.996312
# 3       361207.689490
# 4        11172.328023
#             ...
# 1333     83973.466323
# 1334      3635.702872
# 1335      1984.240014
# 1336      3012.156072
# 1337    634658.661940
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.397371
# 1         2224.738826
# 2        14794.537967
# 3       361215.280069
# 4        11173.748306
#             ...
# 1333     83978.775753
# 1334      3636.323234
# 1335      1984.741068
# 1336      3012.719556
# 1337    634675.782266
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.990852
# 1         2224.661928
# 2        14794.532739
# 3       361216.559515
# 4        11173.879253
#             ...
# 1333     83979.842842
# 1334      3636.247317
# 1335      1984.635683
# 1336      3012.702659
# 1337    634679.913580
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.941029
# 1         2224.486440
# 2        14793.733309
# 3       361211.259159
# 4        11173.016940
#             ...
# 1333     83976.033218
# 1334      3636.012632
# 1335      1984.479591
# 1336      3012.421387
# 1337    634666.564875
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.234492
# 1         2224.545930
# 2        14793.701745
# 3       361209.669716
# 4        11172.831969
#             ...
# 1333     83974.834816
# 1334      3636.090426
# 1335      1984.559637
# 1336      3012.428613
# 1337    634661.583333
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.115518
# 1         2224.451968
# 2        14793.834500
# 3       361213.107149
# 4        11173.235844
#             ...
# 1333     83977.345648
# 1334      3635.978352
# 1335      1984.442249
# 1336      3012.463571
# 1337    634672.696605
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.861843
# 1         2224.904001
# 2        14794.996680
# 3       361216.987496
# 4        11174.113528
#             ...
# 1333     83980.010905
# 1334      3636.533217
# 1335      1984.903105
# 1336      3012.886019
# 1337    634678.954580
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.319617
# 1         2224.883392
# 2        14794.694422
# 3       361214.281114
# 4        11173.711546
#             ...
# 1333     83977.937657
# 1334      3636.495937
# 1335      1984.901839
# 1336      3012.776189
# 1337    634671.982591
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.665099
# 1         2225.125725
# 2        14795.816163
# 3       361220.455279
# 4        11174.747802
#             ...
# 1333     83982.813198
# 1334      3636.787016
# 1335      1985.100054
# 1336      3013.109411
# 1337    634686.873777
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.109132
# 1         2224.736393
# 2        14794.556260
# 3       361214.507606
# 4        11173.628025
#             ...
# 1333     83978.509637
# 1334      3636.284480
# 1335      1984.712180
# 1336      3012.671668
# 1337    634673.672807
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.879413
# 1         2224.930495
# 2        14795.013209
# 3       361216.970120
# 4        11174.121567
#             ...
# 1333     83979.849270
# 1334      3636.556571
# 1335      1984.932796
# 1336      3012.882296
# 1337    634678.664044
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.622475
# 1         2224.836473
# 2        14794.568007
# 3       361213.517498
# 4        11173.569691
#             ...
# 1333     83977.488551
# 1334      3636.421748
# 1335      1984.841648
# 1336      3012.707878
# 1337    634669.852787
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.747151
# 1         2225.139054
# 2        14795.791250
# 3       361220.840696
# 4        11174.817026
#             ...
# 1333     83982.809173
# 1334      3636.811860
# 1335      1985.134505
# 1336      3013.119783
# 1337    634687.890236
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.852645
# 1         2224.943006
# 2        14794.915128
# 3       361215.617630
# 4        11173.946842
#             ...
# 1333     83978.880147
# 1334      3636.575259
# 1335      1984.956619
# 1336      3012.858569
# 1337    634674.807842
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.991378
# 1         2224.785594
# 2        14794.370871
# 3       361212.191246
# 4        11173.346995
#             ...
# 1333     83976.567220
# 1334      3636.342110
# 1335      1984.780277
# 1336      3012.621956
# 1337    634666.038705
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.339308
# 1         2224.474497
# 2        14793.890011
# 3       361213.099916
# 4        11173.260941
#             ...
# 1333     83977.404725
# 1334      3636.006330
# 1335      1984.448626
# 1336      3012.482197
# 1337    634671.820900
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.967932
# 1         2224.481227
# 2        14793.540216
# 3       361209.456684
# 4        11172.758314
#             ...
# 1333     83974.633775
# 1334      3636.005029
# 1335      1984.489878
# 1336      3012.389582
# 1337    634661.870117
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.101537
# 1         2224.788131
# 2        14794.380099
# 3       361212.221378
# 4        11173.346908
#             ...
# 1333     83976.586894
# 1334      3636.342906
# 1335      1984.788476
# 1336      3012.628974
# 1337    634666.624972
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.456373
# 1         2224.478434
# 2        14794.025368
# 3       361214.823466
# 4        11173.499445
#             ...
# 1333     83978.557750
# 1334      3636.011118
# 1335      1984.457332
# 1336      3012.533311
# 1337    634676.792896
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.755791
# 1         2224.893901
# 2        14795.166216
# 3       361218.383359
# 4        11174.297461
#             ...
# 1333     83981.255833
# 1334      3636.518546
# 1335      1984.873810
# 1336      3012.899855
# 1337    634683.158878
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.638227
# 1         2224.781457
# 2        14794.757901
# 3       361215.978808
# 4        11173.873539
#             ...
# 1333     83979.551889
# 1334      3636.368680
# 1335      1984.770138
# 1336      3012.749504
# 1337    634677.569388
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.046285
# 1         2224.574901
# 2        14794.236464
# 3       361214.335613
# 4        11173.488063
#             ...
# 1333     83978.412926
# 1334      3636.117243
# 1335      1984.550955
# 1336      3012.578616
# 1337    634674.873751
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.459534
# 1         2225.144066
# 2        14795.708768
# 3       361219.192713
# 4        11174.573491
#             ...
# 1333     83981.725604
# 1334      3636.778674
# 1335      1985.113657
# 1336      3013.066272
# 1337    634682.514237
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.542999
# 1         2224.442313
# 2        14793.635516
# 3       361210.055163
# 4        11172.804104
#             ...
# 1333     83975.454238
# 1334      3635.950062
# 1335      1984.433308
# 1336      3012.381175
# 1337    634663.826985
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.205258
# 1         2224.654540
# 2        14793.947945
# 3       361210.929524
# 4        11173.082048
#             ...
# 1333     83975.470734
# 1334      3636.196178
# 1335      1984.664095
# 1336      3012.522974
# 1337    634664.133627
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.403932
# 1         2224.983723
# 2        14795.344263
# 3       361218.282056
# 4        11174.335912
#             ...
# 1333     83981.188397
# 1334      3636.603136
# 1335      1984.955614
# 1336      3012.953268
# 1337    634682.016564
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.154113
# 1         2224.410419
# 2        14793.515421
# 3       361210.250871
# 4        11172.803983
#             ...
# 1333     83975.305408
# 1334      3635.902619
# 1335      1984.398279
# 1336      3012.335600
# 1337    634664.518016
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.364964
# 1         2224.217159
# 2        14792.960182
# 3       361207.272445
# 4        11172.244988
#             ...
# 1333     83973.424971
# 1334      3635.655122
# 1335      1984.206732
# 1336      3012.128258
# 1337    634658.224081
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.842975
# 1         2224.754318
# 2        14794.914534
# 3       361217.852983
# 4        11174.108138
#             ...
# 1333     83981.051553
# 1334      3636.350025
# 1335      1984.727604
# 1336      3012.802877
# 1337    634683.504811
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.851614
# 1         2224.623842
# 2        14793.884123
# 3       361210.404081
# 4        11172.996691
#             ...
# 1333     83975.274590
# 1334      3636.174749
# 1335      1984.638545
# 1336      3012.502195
# 1337    634662.719506
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.525798
# 1         2224.958219
# 2        14795.419911
# 3       361219.646656
# 4        11174.514876
#             ...
# 1333     83982.212451
# 1334      3636.598288
# 1335      1984.939835
# 1336      3013.002308
# 1337    634686.103047
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.534240
# 1         2224.958215
# 2        14795.264452
# 3       361219.070727
# 4        11174.435738
#             ...
# 1333     83981.425328
# 1334      3636.603203
# 1335      1984.960482
# 1336      3012.976051
# 1337    634684.721043
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.369671
# 1         2224.843896
# 2        14795.031144
# 3       361217.754604
# 4        11174.157808
#             ...
# 1333     83980.807593
# 1334      3636.436094
# 1335      1984.820552
# 1336      3012.847389
# 1337    634682.204873
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.704857
# 1         2224.823351
# 2        14794.614719
# 3       361214.459913
# 4        11173.700576
#             ...
# 1333     83978.150890
# 1334      3636.429538
# 1335      1984.832270
# 1336      3012.743264
# 1337    634672.278888
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.886514
# 1         2224.840517
# 2        14794.554692
# 3       361213.097453
# 4        11173.519721
#             ...
# 1333     83977.254004
# 1334      3636.432342
# 1335      1984.842005
# 1336      3012.718083
# 1337    634668.581244
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.247712
# 1         2224.357535
# 2        14793.742142
# 3       361212.556926
# 4        11173.081157
#             ...
# 1333     83977.417165
# 1334      3635.849759
# 1335      1984.322820
# 1336      3012.387420
# 1337    634672.181670
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.148967
# 1         2224.364959
# 2        14793.409909
# 3       361210.452816
# 4        11172.814410
#             ...
# 1333     83975.381306
# 1334      3635.868597
# 1335      1984.370546
# 1336      3012.340329
# 1337    634665.788834
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.261698
# 1         2224.428581
# 2        14793.602010
# 3       361210.486840
# 4        11172.848449
#             ...
# 1333     83975.571590
# 1334      3635.918420
# 1335      1984.404135
# 1336      3012.345101
# 1337    634664.771880
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.880405
# 1         2224.502547
# 2        14793.794939
# 3       361211.522254
# 4        11173.055443
#             ...
# 1333     83976.223456
# 1334      3636.020897
# 1335      1984.486339
# 1336      3012.429159
# 1337    634667.069676
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.833436
# 1         2224.579798
# 2        14793.931698
# 3       361212.021931
# 4        11173.181875
#             ...
# 1333     83976.387663
# 1334      3636.143606
# 1335      1984.593739
# 1336      3012.535009
# 1337    634668.035317
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.791853
# 1         2224.141751
# 2        14792.754242
# 3       361206.327633
# 4        11172.064224
#             ...
# 1333     83972.833061
# 1334      3635.568751
# 1335      1984.114445
# 1336      3012.044767
# 1337    634656.076473
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.273589
# 1         2224.278759
# 2        14793.228609
# 3       361209.488761
# 4        11172.612551
#             ...
# 1333     83974.914776
# 1334      3635.758147
# 1335      1984.255707
# 1336      3012.249062
# 1337    634663.541636
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.267273
# 1         2224.493578
# 2        14794.092110
# 3       361213.910480
# 4        11173.374440
#             ...
# 1333     83978.309334
# 1334      3636.019723
# 1335      1984.460410
# 1336      3012.513114
# 1337    634674.406713
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.108655
# 1         2224.174876
# 2        14792.853299
# 3       361206.925396
# 4        11172.165428
#             ...
# 1333     83973.170441
# 1334      3635.594013
# 1335      1984.150155
# 1336      3012.094983
# 1337    634657.135039
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.928727
# 1         2224.511351
# 2        14793.792300
# 3       361210.922483
# 4        11172.958816
#             ...
# 1333     83975.834882
# 1334      3636.007089
# 1335      1984.492251
# 1336      3012.427503
# 1337    634665.369990
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.015965
# 1         2224.443328
# 2        14793.837592
# 3       361213.036131
# 4        11173.216756
#             ...
# 1333     83977.381877
# 1334      3635.970872
# 1335      1984.430354
# 1336      3012.455804
# 1337    634672.692504
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.490387
# 1         2224.397413
# 2        14793.736965
# 3       361211.781820
# 4        11173.007207
#             ...
# 1333     83976.828611
# 1334      3635.898654
# 1335      1984.376073
# 1336      3012.401331
# 1337    634669.650435
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.109011
# 1         2224.143396
# 2        14792.806780
# 3       361207.560574
# 4        11172.240579
#             ...
# 1333     83973.517734
# 1334      3635.579930
# 1335      1984.115818
# 1336      3012.098502
# 1337    634659.266835
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.540729
# 1         2224.103134
# 2        14792.570622
# 3       361206.279642
# 4        11172.030282
#             ...
# 1333     83972.425762
# 1334      3635.526729
# 1335      1984.091817
# 1336      3012.034285
# 1337    634656.104247
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.236409
# 1         2225.124123
# 2        14795.571192
# 3       361218.700127
# 4        11174.503110
#             ...
# 1333     83981.228440
# 1334      3636.775901
# 1335      1985.111313
# 1336      3013.044046
# 1337    634681.453371
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.555340
# 1         2224.297455
# 2        14793.147078
# 3       361208.800784
# 4        11172.531581
#             ...
# 1333     83974.211759
# 1334      3635.789306
# 1335      1984.295207
# 1336      3012.245396
# 1337    634661.734369
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.243204
# 1         2224.555135
# 2        14794.434825
# 3       361216.292707
# 4        11173.755164
#             ...
# 1333     83980.101362
# 1334      3636.110549
# 1335      1984.523804
# 1336      3012.633268
# 1337    634681.001517
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.459411
# 1         2224.798387
# 2        14794.347455
# 3       361211.953696
# 4        11173.330226
#             ...
# 1333     83976.334429
# 1334      3636.388258
# 1335      1984.814005
# 1336      3012.664384
# 1337    634665.747168
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.296844
# 1         2224.773901
# 2        14794.369606
# 3       361213.021083
# 4        11173.464170
#             ...
# 1333     83977.030037
# 1334      3636.367687
# 1335      1984.788541
# 1336      3012.675136
# 1337    634668.850202
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.316481
# 1         2225.175147
# 2        14795.904161
# 3       361220.687514
# 4        11174.816455
#             ...
# 1333     83982.886535
# 1334      3636.850457
# 1335      1985.153719
# 1336      3013.165664
# 1337    634687.263406
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.865169
# 1         2225.011625
# 2        14795.434097
# 3       361219.752939
# 4        11174.572584
#             ...
# 1333     83981.954880
# 1334      3636.664701
# 1335      1984.999932
# 1336      3013.018891
# 1337    634685.831037
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.315493
# 1         2224.291873
# 2        14793.164330
# 3       361208.844704
# 4        11172.523709
#             ...
# 1333     83974.292585
# 1334      3635.763981
# 1335      1984.278597
# 1336      3012.240198
# 1337    634661.556884
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.388157
# 1         2225.195784
# 2        14795.899351
# 3       361220.885105
# 4        11174.848996
#             ...
# 1333     83982.773267
# 1334      3636.870640
# 1335      1985.186812
# 1336      3013.185340
# 1337    634687.571402
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.297116
# 1         2224.604762
# 2        14794.578934
# 3       361216.803811
# 4        11173.861715
#             ...
# 1333     83980.475402
# 1334      3636.150717
# 1335      1984.561418
# 1336      3012.649992
# 1337    634681.454182
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.934188
# 1         2225.153464
# 2        14795.821095
# 3       361221.391689
# 4        11174.901254
#             ...
# 1333     83983.016070
# 1334      3636.827127
# 1335      1985.141719
# 1336      3013.150989
# 1337    634688.729664
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.104081
# 1         2224.506616
# 2        14793.827893
# 3       361211.967871
# 4        11173.126670
#             ...
# 1333     83976.505687
# 1334      3636.031078
# 1335      1984.494883
# 1336      3012.444065
# 1337    634668.308457
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.280160
# 1         2224.690560
# 2        14794.201971
# 3       361211.558322
# 4        11173.175382
#             ...
# 1333     83976.319191
# 1334      3636.202888
# 1335      1984.671439
# 1336      3012.543964
# 1337    634665.627899
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.157471
# 1         2224.260329
# 2        14792.966246
# 3       361207.824054
# 4        11172.364460
#             ...
# 1333     83973.396225
# 1334      3635.729849
# 1335      1984.255292
# 1336      3012.191970
# 1337    634658.990814
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.751609
# 1         2224.821044
# 2        14794.723201
# 3       361215.133857
# 4        11173.769223
#             ...
# 1333     83978.751527
# 1334      3636.387845
# 1335      1984.802668
# 1336      3012.738550
# 1337    634674.594315
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.681830
# 1         2224.492545
# 2        14794.128258
# 3       361214.672035
# 4        11173.479114
#             ...
# 1333     83978.749933
# 1334      3636.024588
# 1335      1984.465489
# 1336      3012.551367
# 1337    634676.879889
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.245212
# 1         2224.918517
# 2        14795.143000
# 3       361218.223430
# 4        11174.296312
#             ...
# 1333     83980.954540
# 1334      3636.561752
# 1335      1984.920807
# 1336      3012.945194
# 1337    634682.790418
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.409016
# 1         2224.835703
# 2        14794.977938
# 3       361218.092116
# 4        11174.208087
#             ...
# 1333     83980.835036
# 1334      3636.451174
# 1335      1984.820948
# 1336      3012.874486
# 1337    634682.691327
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.956905
# 1         2224.741283
# 2        14794.180222
# 3       361212.103644
# 4        11173.327525
#             ...
# 1333     83976.252984
# 1334      3636.335414
# 1335      1984.766462
# 1336      3012.619659
# 1337    634666.493635
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.525226
# 1         2224.647603
# 2        14794.316611
# 3       361214.494963
# 4        11173.570417
#             ...
# 1333     83978.284008
# 1334      3636.210432
# 1335      1984.630328
# 1336      3012.630470
# 1337    634674.130941
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.294081
# 1         2224.155517
# 2        14792.904841
# 3       361207.628862
# 4        11172.261084
#             ...
# 1333     83973.831629
# 1334      3635.612381
# 1335      1984.138310
# 1336      3012.109418
# 1337    634660.082905
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.168173
# 1         2224.003525
# 2        14792.274342
# 3       361205.072051
# 4        11171.802725
#             ...
# 1333     83971.604432
# 1334      3635.447652
# 1335      1984.013879
# 1336      3011.969134
# 1337    634654.251348
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.173386
# 1         2224.717819
# 2        14794.601524
# 3       361216.081898
# 4        11173.841600
#             ...
# 1333     83979.482475
# 1334      3636.306312
# 1335      1984.710009
# 1336      3012.722612
# 1337    634678.457043
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.535419
# 1         2224.447772
# 2        14793.612709
# 3       361210.193215
# 4        11172.819533
#             ...
# 1333     83975.345999
# 1334      3635.923765
# 1335      1984.422837
# 1336      3012.355312
# 1337    634663.837676
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.263590
# 1         2224.908982
# 2        14795.264059
# 3       361219.312899
# 4        11174.428809
#             ...
# 1333     83981.856626
# 1334      3636.533844
# 1335      1984.888469
# 1336      3012.953723
# 1337    634686.127705
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.364816
# 1         2225.079305
# 2        14795.681512
# 3       361220.144356
# 4        11174.667641
#             ...
# 1333     83982.499749
# 1334      3636.722732
# 1335      1985.051365
# 1336      3013.066810
# 1337    634686.307148
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.485504
# 1         2224.674243
# 2        14794.226794
# 3       361212.832872
# 4        11173.362571
#             ...
# 1333     83977.109171
# 1334      3636.225842
# 1335      1984.657731
# 1336      3012.578953
# 1337    634669.134236
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.718800
# 1         2224.427098
# 2        14793.902932
# 3       361212.885975
# 4        11173.170568
#             ...
# 1333     83977.623928
# 1334      3635.906415
# 1335      1984.379990
# 1336      3012.426176
# 1337    634672.374385
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.162948
# 1         2224.724106
# 2        14794.536086
# 3       361214.756190
# 4        11173.659655
#             ...
# 1333     83978.653349
# 1334      3636.288900
# 1335      1984.715641
# 1336      3012.693831
# 1337    634674.712888
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.473207
# 1         2224.198446
# 2        14792.928715
# 3       361208.451625
# 4        11172.414460
#             ...
# 1333     83973.973804
# 1334      3635.650751
# 1335      1984.180974
# 1336      3012.149881
# 1337    634661.049907
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.697569
# 1         2224.770428
# 2        14794.740442
# 3       361216.375669
# 4        11173.921887
#             ...
# 1333     83979.721392
# 1334      3636.337545
# 1335      1984.739904
# 1336      3012.757745
# 1337    634678.282281
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.178725
# 1         2224.384218
# 2        14793.426333
# 3       361209.213435
# 4        11172.633863
#             ...
# 1333     83974.712426
# 1334      3635.862134
# 1335      1984.370193
# 1336      3012.310371
# 1337    634662.116711
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.931339
# 1         2224.660494
# 2        14794.264875
# 3       361213.924956
# 4        11173.509268
#             ...
# 1333     83977.809926
# 1334      3636.242648
# 1335      1984.664206
# 1336      3012.649151
# 1337    634672.826260
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.538262
# 1         2224.263938
# 2        14793.390652
# 3       361211.441295
# 4        11172.873124
#             ...
# 1333     83976.390885
# 1334      3635.746067
# 1335      1984.233354
# 1336      3012.301231
# 1337    634669.433141
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.746100
# 1         2224.632386
# 2        14794.580061
# 3       361217.080440
# 4        11173.923037
#             ...
# 1333     83980.405830
# 1334      3636.200501
# 1335      1984.597378
# 1336      3012.701592
# 1337    634681.712165
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.811775
# 1         2224.735326
# 2        14794.253037
# 3       361212.065430
# 4        11173.293629
#             ...
# 1333     83976.455647
# 1334      3636.310019
# 1335      1984.751236
# 1336      3012.624152
# 1337    634666.578670
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.306936
# 1         2225.097935
# 2        14795.543706
# 3       361219.015237
# 4        11174.525621
#             ...
# 1333     83981.427615
# 1334      3636.754087
# 1335      1985.083254
# 1336      3013.051246
# 1337    634682.719589
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.928913
# 1         2224.631246
# 2        14794.473556
# 3       361216.054997
# 4        11173.785461
#             ...
# 1333     83979.628755
# 1334      3636.199699
# 1335      1984.602729
# 1336      3012.683622
# 1337    634678.986568
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.096361
# 1         2224.407439
# 2        14793.480442
# 3       361209.062187
# 4        11172.624866
#             ...
# 1333     83974.673113
# 1334      3635.887587
# 1335      1984.395217
# 1336      3012.311603
# 1337    634661.444839
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.034106
# 1         2224.686025
# 2        14794.654507
# 3       361216.550328
# 4        11173.877800
#             ...
# 1333     83980.057735
# 1334      3636.259196
# 1335      1984.662323
# 1336      3012.722436
# 1337    634680.063242
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.399254
# 1         2224.415144
# 2        14793.504388
# 3       361210.534769
# 4        11172.852022
#             ...
# 1333     83975.369462
# 1334      3635.924602
# 1335      1984.411467
# 1336      3012.355303
# 1337    634665.463308
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.935299
# 1         2224.262768
# 2        14792.959896
# 3       361207.604305
# 4        11172.346950
#             ...
# 1333     83973.304529
# 1334      3635.731280
# 1335      1984.253440
# 1336      3012.168890
# 1337    634658.005272
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.037977
# 1         2224.544630
# 2        14794.220126
# 3       361214.768043
# 4        11173.531937
#             ...
# 1333     83978.768446
# 1334      3636.090832
# 1335      1984.525602
# 1336      3012.594144
# 1337    634676.606905
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.082003
# 1         2224.600272
# 2        14794.137260
# 3       361212.881797
# 4        11173.315608
#             ...
# 1333     83977.315078
# 1334      3636.149357
# 1335      1984.587296
# 1336      3012.544344
# 1337    634670.263056
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.745205
# 1         2224.829779
# 2        14794.933777
# 3       361217.773110
# 4        11174.167509
#             ...
# 1333     83980.619900
# 1334      3636.462891
# 1335      1984.828728
# 1336      3012.883761
# 1337    634682.434510
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.361799
# 1         2225.063846
# 2        14795.578077
# 3       361220.522526
# 4        11174.715400
#             ...
# 1333     83982.415878
# 1334      3636.726416
# 1335      1985.049238
# 1336      3013.068642
# 1337    634687.531453
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.567374
# 1         2224.474136
# 2        14794.206644
# 3       361215.289607
# 4        11173.553745
#             ...
# 1333     83979.411365
# 1334      3636.002826
# 1335      1984.423098
# 1336      3012.542607
# 1337    634678.630610
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.731597
# 1         2225.261648
# 2        14796.132250
# 3       361221.696112
# 4        11175.009948
#             ...
# 1333     83983.489256
# 1334      3636.949792
# 1335      1985.250265
# 1336      3013.242095
# 1337    634689.132495
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.526107
# 1         2225.018994
# 2        14795.141156
# 3       361216.654199
# 4        11174.147623
#             ...
# 1333     83979.601905
# 1334      3636.663950
# 1335      1985.038353
# 1336      3012.949113
# 1337    634677.075034
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.181703
# 1         2224.981375
# 2        14795.006809
# 3       361215.697192
# 4        11173.979814
#             ...
# 1333     83978.945091
# 1334      3636.605364
# 1335      1984.990867
# 1336      3012.881475
# 1337    634674.597090
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.745959
# 1         2225.167455
# 2        14795.817371
# 3       361220.081715
# 4        11174.724255
#             ...
# 1333     83982.367877
# 1334      3636.829396
# 1335      1985.151953
# 1336      3013.109781
# 1337    634685.261971
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.711817
# 1         2225.119373
# 2        14795.853964
# 3       361221.106467
# 4        11174.840793
#             ...
# 1333     83983.272275
# 1334      3636.788872
# 1335      1985.093715
# 1336      3013.119338
# 1337    634688.622069
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.036125
# 1         2224.251449
# 2        14792.931541
# 3       361207.362228
# 4        11172.292398
#             ...
# 1333     83973.149787
# 1334      3635.711073
# 1335      1984.248406
# 1336      3012.173320
# 1337    634658.054017
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.405866
# 1         2224.307139
# 2        14793.252989
# 3       361209.033367
# 4        11172.566219
#             ...
# 1333     83974.591011
# 1334      3635.777221
# 1335      1984.286356
# 1336      3012.231988
# 1337    634661.990628
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.696860
# 1         2224.849375
# 2        14794.623812
# 3       361214.035820
# 4        11173.648820
#             ...
# 1333     83977.809116
# 1334      3636.439458
# 1335      1984.857962
# 1336      3012.736239
# 1337    634671.177448
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.497955
# 1         2225.004661
# 2        14795.199350
# 3       361217.183339
# 4        11174.210097
#             ...
# 1333     83980.109697
# 1334      3636.657327
# 1335      1985.008442
# 1336      3012.950886
# 1337    634678.460843
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.234959
# 1         2224.843359
# 2        14794.818309
# 3       361216.527814
# 4        11173.998543
#             ...
# 1333     83979.582502
# 1334      3636.460830
# 1335      1984.847001
# 1336      3012.823262
# 1337    634678.345172
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.225055
# 1         2224.992788
# 2        14795.351342
# 3       361218.029735
# 4        11174.294763
#             ...
# 1333     83981.007301
# 1334      3636.612591
# 1335      1984.979372
# 1336      3012.948176
# 1337    634681.382225
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.229659
# 1         2224.452124
# 2        14793.510902
# 3       361208.766025
# 4        11172.621405
#             ...
# 1333     83974.378821
# 1334      3635.935628
# 1335      1984.448984
# 1336      3012.326172
# 1337    634660.071279
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.020396
# 1         2224.813716
# 2        14794.756800
# 3       361215.819993
# 4        11173.886235
#             ...
# 1333     83979.312063
# 1334      3636.437145
# 1335      1984.816811
# 1336      3012.787548
# 1337    634676.929023
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.444607
# 1         2224.993669
# 2        14795.460617
# 3       361218.997062
# 4        11174.428595
#             ...
# 1333     83981.772502
# 1334      3636.596547
# 1335      1984.951978
# 1336      3012.975205
# 1337    634683.770528
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.548561
# 1         2224.488861
# 2        14793.673479
# 3       361210.281831
# 4        11172.869229
#             ...
# 1333     83975.344130
# 1334      3635.982862
# 1335      1984.468726
# 1336      3012.375115
# 1337    634663.227301
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.435766
# 1         2224.195469
# 2        14792.930933
# 3       361207.324343
# 4        11172.238682
#             ...
# 1333     83973.486305
# 1334      3635.619701
# 1335      1984.168058
# 1336      3012.117049
# 1337    634658.418094
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.675371
# 1         2224.498097
# 2        14794.178531
# 3       361215.924797
# 4        11173.671583
#             ...
# 1333     83979.448002
# 1334      3636.039338
# 1335      1984.468686
# 1336      3012.580674
# 1337    634679.747753
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.708672
# 1         2225.044954
# 2        14795.338705
# 3       361217.920807
# 4        11174.337684
#             ...
# 1333     83980.616204
# 1334      3636.678761
# 1335      1985.037421
# 1336      3012.981865
# 1337    634679.953706
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.794101
# 1         2224.967907
# 2        14795.384674
# 3       361219.653624
# 4        11174.527023
#             ...
# 1333     83982.045763
# 1334      3636.622455
# 1335      1984.959344
# 1336      3013.020171
# 1337    634686.314936
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.974106
# 1         2224.863103
# 2        14794.759833
# 3       361214.675399
# 4        11173.745555
#             ...
# 1333     83978.446139
# 1334      3636.449876
# 1335      1984.857553
# 1336      3012.764595
# 1337    634672.840276
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.040159
# 1         2224.321428
# 2        14793.437602
# 3       361210.619260
# 4        11172.800522
#             ...
# 1333     83975.832166
# 1334      3635.819047
# 1335      1984.299859
# 1336      3012.326661
# 1337    634666.870141
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.310683
# 1         2225.017180
# 2        14795.192737
# 3       361216.399035
# 4        11174.107615
#             ...
# 1333     83979.675113
# 1334      3636.661776
# 1335      1985.021529
# 1336      3012.921845
# 1337    634676.188268
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.227306
# 1         2224.438098
# 2        14793.957151
# 3       361214.682888
# 4        11173.459406
#             ...
# 1333     83978.574389
# 1334      3635.993285
# 1335      1984.421965
# 1336      3012.522401
# 1337    634676.910256
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.825509
# 1         2224.260088
# 2        14793.141706
# 3       361208.448594
# 4        11172.436057
#             ...
# 1333     83974.220424
# 1334      3635.691161
# 1335      1984.225162
# 1336      3012.177516
# 1337    634660.482040
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.892958
# 1         2224.651799
# 2        14794.554068
# 3       361216.079635
# 4        11173.783579
#             ...
# 1333     83979.732352
# 1334      3636.219843
# 1335      1984.628752
# 1336      3012.703418
# 1337    634679.248330
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.585736
# 1         2224.088719
# 2        14792.489810
# 3       361206.169332
# 4        11172.027886
#             ...
# 1333     83972.255514
# 1334      3635.542617
# 1335      1984.092474
# 1336      3012.023228
# 1337    634655.706483
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.230534
# 1         2224.746084
# 2        14794.597522
# 3       361214.783159
# 4        11173.677943
#             ...
# 1333     83978.714042
# 1334      3636.306256
# 1335      1984.716651
# 1336      3012.688676
# 1337    634674.117084
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.116179
# 1         2224.732182
# 2        14794.560757
# 3       361215.298868
# 4        11173.735140
#             ...
# 1333     83978.880167
# 1334      3636.286410
# 1335      1984.708767
# 1336      3012.701375
# 1337    634675.644115
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.370692
# 1         2224.980348
# 2        14795.486523
# 3       361219.798387
# 4        11174.538539
#             ...
# 1333     83982.312790
# 1334      3636.600836
# 1335      1984.939645
# 1336      3012.979823
# 1337    634686.123407
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.543720
# 1         2224.755205
# 2        14794.905686
# 3       361217.766990
# 4        11174.106719
#             ...
# 1333     83981.003863
# 1334      3636.341042
# 1335      1984.723352
# 1336      3012.780526
# 1337    634682.629844
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.978538
# 1         2224.573070
# 2        14794.150519
# 3       361213.644209
# 4        11173.401392
#             ...
# 1333     83977.881158
# 1334      3636.117825
# 1335      1984.560044
# 1336      3012.567001
# 1337    634672.935713
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.422086
# 1         2224.367063
# 2        14793.706683
# 3       361212.262469
# 4        11173.053062
#             ...
# 1333     83977.122365
# 1334      3635.866997
# 1335      1984.332903
# 1336      3012.397367
# 1337    634671.080210
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.927706
# 1         2224.894295
# 2        14795.215943
# 3       361218.297606
# 4        11174.276959
#             ...
# 1333     83981.365244
# 1334      3636.509995
# 1335      1984.862586
# 1336      3012.917582
# 1337    634683.013481
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.505469
# 1         2225.126611
# 2        14795.679085
# 3       361219.526019
# 4        11174.618373
#             ...
# 1333     83981.909480
# 1334      3636.773118
# 1335      1985.099921
# 1336      3013.082892
# 1337    634683.376236
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.983997
# 1         2224.463163
# 2        14793.752325
# 3       361212.035380
# 4        11173.099089
#             ...
# 1333     83976.543992
# 1334      3635.988319
# 1335      1984.452062
# 1336      3012.436959
# 1337    634669.100493
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.605035
# 1         2224.500049
# 2        14793.668055
# 3       361209.292813
# 4        11172.723745
#             ...
# 1333     83974.805579
# 1334      3635.989930
# 1335      1984.487687
# 1336      3012.359979
# 1337    634661.179588
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.913631
# 1         2224.737092
# 2        14794.808596
# 3       361218.318647
# 4        11174.186580
#             ...
# 1333     83981.055370
# 1334      3636.342273
# 1335      1984.711616
# 1336      3012.820712
# 1337    634684.049947
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.249559
# 1         2224.891767
# 2        14794.622860
# 3       361213.566546
# 4        11173.621842
#             ...
# 1333     83977.332161
# 1334      3636.502889
# 1335      1984.910260
# 1336      3012.773554
# 1337    634669.180269
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.273252
# 1         2224.310972
# 2        14793.348994
# 3       361209.154000
# 4        11172.566990
#             ...
# 1333     83974.911940
# 1334      3635.765793
# 1335      1984.284154
# 1336      3012.233508
# 1337    634662.835628
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.257630
# 1         2224.520826
# 2        14793.892619
# 3       361211.506355
# 4        11173.061489
#             ...
# 1333     83976.414617
# 1334      3636.046520
# 1335      1984.507087
# 1336      3012.465315
# 1337    634667.049856
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.399933
# 1         2225.192446
# 2        14795.951762
# 3       361221.592322
# 4        11174.957739
#             ...
# 1333     83983.311291
# 1334      3636.864599
# 1335      1985.174254
# 1336      3013.185294
# 1337    634689.405752
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.434893
# 1         2224.776518
# 2        14794.658579
# 3       361214.757995
# 4        11173.689264
#             ...
# 1333     83978.688715
# 1334      3636.338082
# 1335      1984.752284
# 1336      3012.716773
# 1337    634673.794438
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.589390
# 1         2224.997901
# 2        14795.357436
# 3       361218.735134
# 4        11174.416672
#             ...
# 1333     83981.345227
# 1334      3636.631725
# 1335      1984.987174
# 1336      3012.971027
# 1337    634683.273817
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.374526
# 1         2224.055620
# 2        14792.487787
# 3       361206.288256
# 4        11171.998981
#             ...
# 1333     83972.456231
# 1334      3635.480604
# 1335      1984.040027
# 1336      3012.003824
# 1337    634656.641324
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.162561
# 1         2224.863464
# 2        14794.718667
# 3       361214.644005
# 4        11173.760631
#             ...
# 1333     83978.342490
# 1334      3636.471293
# 1335      1984.865120
# 1336      3012.775461
# 1337    634672.520183
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.117560
# 1         2225.129879
# 2        14795.612048
# 3       361218.501223
# 4        11174.465011
#             ...
# 1333     83981.191153
# 1334      3636.755190
# 1335      1985.107957
# 1336      3013.028444
# 1337    634680.713318
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.908078
# 1         2224.395004
# 2        14793.349648
# 3       361208.846167
# 4        11172.608475
#             ...
# 1333     83974.273412
# 1334      3635.885007
# 1335      1984.384388
# 1336      3012.277677
# 1337    634660.409342
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.214362
# 1         2224.706882
# 2        14794.428989
# 3       361214.991165
# 4        11173.701207
# ...
# 1         2224.192937
# 2        14793.001818
# 3       361207.901168
# 4        11172.320541
#             ...
# 1333     83974.024550
# 1334      3635.647295
# 1335      1984.174746
# 1336      3012.150350
# 1337    634660.453751
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.541171
# 1         2224.534375
# 2        14793.860419
# 3       361212.022883
# 4        11173.158411
#             ...
# 1333     83976.464238
# 1334      3636.081425
# 1335      1984.530181
# 1336      3012.503901
# 1337    634667.937002
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.629139
# 1         2224.230739
# 2        14792.883409
# 3       361207.227237
# 4        11172.251998
#             ...
# 1333     83973.037777
# 1334      3635.679558
# 1335      1984.222521
# 1336      3012.139969
# 1337    634657.605735
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.553736
# 1         2224.859030
# 2        14794.929410
# 3       361216.979693
# 4        11174.073879
#             ...
# 1333     83980.054655
# 1334      3636.477536
# 1335      1984.848246
# 1336      3012.857252
# 1337    634679.355619
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.342136
# 1         2224.999629
# 2        14795.202583
# 3       361217.204324
# 4        11174.207542
#             ...
# 1333     83980.169120
# 1334      3636.635446
# 1335      1985.008468
# 1336      3012.942980
# 1337    634678.805641
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.881487
# 1         2224.117303
# 2        14792.706189
# 3       361207.762335
# 4        11172.259613
#             ...
# 1333     83973.440997
# 1334      3635.562595
# 1335      1984.103484
# 1336      3012.084397
# 1337    634659.697400
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.392849
# 1         2224.544494
# 2        14793.867986
# 3       361211.160741
# 4        11173.031901
#             ...
# 1333     83976.027648
# 1334      3636.084512
# 1335      1984.542865
# 1336      3012.468025
# 1337    634665.926023
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.126395
# 1         2224.616659
# 2        14794.004023
# 3       361211.858401
# 4        11173.188908
#             ...
# 1333     83976.338863
# 1334      3636.175309
# 1335      1984.626680
# 1336      3012.532631
# 1337    634667.563006
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.173719
# 1         2224.329582
# 2        14793.496249
# 3       361211.039901
# 4        11172.866763
#             ...
# 1333     83976.161244
# 1334      3635.832206
# 1335      1984.307465
# 1336      3012.346643
# 1337    634667.951157
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.087968
# 1         2224.366370
# 2        14793.567159
# 3       361210.613806
# 4        11172.816639
#             ...
# 1333     83975.940593
# 1334      3635.856726
# 1335      1984.349210
# 1336      3012.325541
# 1337    634666.982155
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.440322
# 1         2224.702081
# 2        14794.695380
# 3       361216.873621
# 4        11173.939089
#             ...
# 1333     83980.251080
# 1334      3636.279037
# 1335      1984.676024
# 1336      3012.753402
# 1337    634681.134541
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.622528
# 1         2224.523166
# 2        14793.734524
# 3       361209.499469
# 4        11172.771729
#             ...
# 1333     83974.983120
# 1334      3636.016118
# 1335      1984.517706
# 1336      3012.372810
# 1337    634661.581772
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.401863
# 1         2225.217504
# 2        14795.931399
# 3       361220.953248
# 4        11174.870474
#             ...
# 1333     83982.745263
# 1334      3636.887341
# 1335      1985.203438
# 1336      3013.173590
# 1337    634687.431927
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.858642
# 1         2224.476854
# 2        14793.518690
# 3       361209.116875
# 4        11172.702713
#             ...
# 1333     83974.427002
# 1334      3636.002683
# 1335      1984.486377
# 1336      3012.371358
# 1337    634661.014269
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.345627
# 1         2224.434321
# 2        14793.567260
# 3       361209.546277
# 4        11172.724631
#             ...
# 1333     83975.051028
# 1334      3635.942435
# 1335      1984.426237
# 1336      3012.337369
# 1337    634662.738531
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.539542
# 1         2224.474483
# 2        14794.124060
# 3       361215.790992
# 4        11173.630876
#             ...
# 1333     83979.341020
# 1334      3636.017735
# 1335      1984.443703
# 1336      3012.561192
# 1337    634679.684764
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.773379
# 1         2224.790839
# 2        14794.831931
# 3       361216.711274
# 4        11173.984642
#             ...
# 1333     83980.062880
# 1334      3636.388091
# 1335      1984.770976
# 1336      3012.781122
# 1337    634679.360767
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.275659
# 1         2224.306843
# 2        14793.297055
# 3       361209.211062
# 4        11172.588965
#             ...
# 1333     83974.820871
# 1334      3635.776355
# 1335      1984.278432
# 1336      3012.232082
# 1337    634662.378616
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.238134
# 1         2224.794585
# 2        14794.429628
# 3       361212.485593
# 4        11173.395969
#             ...
# 1333     83976.848373
# 1334      3636.367248
# 1335      1984.800766
# 1336      3012.661528
# 1337    634667.074544
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.559056
# 1         2224.774744
# 2        14794.794283
# 3       361216.308483
# 4        11173.911091
#             ...
# 1333     83979.861708
# 1334      3636.356411
# 1335      1984.746604
# 1336      3012.759676
# 1337    634678.426233
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.808106
# 1         2224.739620
# 2        14794.744100
# 3       361217.254726
# 4        11174.032763
#             ...
# 1333     83980.351579
# 1334      3636.344283
# 1335      1984.732259
# 1336      3012.791652
# 1337    634681.534417
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.031578
# 1         2224.668898
# 2        14794.506564
# 3       361216.223442
# 4        11173.831649
#             ...
# 1333     83979.556505
# 1334      3636.254198
# 1335      1984.661466
# 1336      3012.711852
# 1337    634679.337756
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.153414
# 1         2224.954220
# 2        14795.223129
# 3       361218.098253
# 4        11174.296827
#             ...
# 1333     83980.914462
# 1334      3636.589476
# 1335      1984.943798
# 1336      3012.942807
# 1337    634681.696973
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.507674
# 1         2224.183474
# 2        14792.887497
# 3       361207.210862
# 4        11172.209611
#             ...
# 1333     83973.357575
# 1334      3635.629883
# 1335      1984.168286
# 1336      3012.127371
# 1337    634658.563149
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.638206
# 1         2224.723426
# 2        14794.849061
# 3       361217.796854
# 4        11174.089669
#             ...
# 1333     83981.051119
# 1334      3636.315224
# 1335      1984.694329
# 1336      3012.780975
# 1337    634683.585269
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.142160
# 1         2224.071352
# 2        14792.543387
# 3       361205.755326
# 4        11171.931808
#             ...
# 1333     83972.309043
# 1334      3635.481901
# 1335      1984.055443
# 1336      3011.984939
# 1337    634654.835170
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.561319
# 1         2224.645243
# 2        14794.537997
# 3       361215.989617
# 4        11173.771637
#             ...
# 1333     83979.694599
# 1334      3636.191784
# 1335      1984.609433
# 1336      3012.650438
# 1337    634678.832912
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.796827
# 1         2224.134183
# 2        14792.654936
# 3       361206.273521
# 4        11172.053743
#             ...
# 1333     83972.505896
# 1334      3635.560911
# 1335      1984.121984
# 1336      3012.049471
# 1337    634655.710427
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.958689
# 1         2224.665097
# 2        14794.635247
# 3       361216.434405
# 4        11173.836996
#             ...
# 1333     83980.046875
# 1334      3636.212400
# 1335      1984.620003
# 1336      3012.688628
# 1337    634680.066988
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.760382
# 1         2224.671049
# 2        14794.335172
# 3       361214.202746
# 4        11173.551345
#             ...
# 1333     83978.096807
# 1334      3636.232090
# 1335      1984.661077
# 1336      3012.631308
# 1337    634673.590843
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.792578
# 1         2224.572426
# 2        14793.980725
# 3       361212.083940
# 4        11173.191267
#             ...
# 1333     83976.657708
# 1334      3636.116682
# 1335      1984.568682
# 1336      3012.509129
# 1337    634668.384450
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.879484
# 1         2224.846739
# 2        14794.766357
# 3       361215.387648
# 4        11173.837029
#             ...
# 1333     83978.895545
# 1334      3636.434495
# 1335      1984.840695
# 1336      3012.767417
# 1337    634675.091366
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.316070
# 1         2224.353761
# 2        14793.607863
# 3       361211.591842
# 4        11172.959493
#             ...
# 1333     83976.604932
# 1334      3635.862502
# 1335      1984.329604
# 1336      3012.368903
# 1337    634669.133272
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.090658
# 1         2225.090615
# 2        14795.494536
# 3       361218.054059
# 4        11174.375454
#             ...
# 1333     83980.858738
# 1334      3636.714725
# 1335      1985.068884
# 1336      3013.007633
# 1337    634680.009352
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.917297
# 1         2224.398455
# 2        14793.452559
# 3       361209.215946
# 4        11172.643621
#             ...
# 1333     83974.697796
# 1334      3635.855937
# 1335      1984.369943
# 1336      3012.278756
# 1337    634661.525179
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.045804
# 1         2224.631918
# 2        14794.066494
# 3       361211.197771
# 4        11173.091194
#             ...
# 1333     83976.121160
# 1334      3636.168433
# 1335      1984.616301
# 1336      3012.528461
# 1337    634665.113278
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.877150
# 1         2224.723695
# 2        14794.229039
# 3       361212.762164
# 4        11173.396725
#             ...
# 1333     83976.776566
# 1334      3636.309975
# 1335      1984.741048
# 1336      3012.631348
# 1337    634668.390938
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.521666
# 1         2224.733130
# 2        14794.663595
# 3       361216.898120
# 4        11173.969887
#             ...
# 1333     83979.932021
# 1334      3636.322258
# 1335      1984.718129
# 1336      3012.753457
# 1337    634680.394059
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.432090
# 1         2224.702753
# 2        14794.567826
# 3       361216.459958
# 4        11173.899713
#             ...
# 1333     83979.670878
# 1334      3636.293895
# 1335      1984.697036
# 1336      3012.738921
# 1337    634679.638951
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.899212
# 1         2224.775212
# 2        14794.815467
# 3       361217.350311
# 4        11174.066722
#             ...
# 1333     83980.391246
# 1334      3636.370191
# 1335      1984.751955
# 1336      3012.799860
# 1337    634681.314555
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.175757
# 1         2224.992476
# 2        14795.113263
# 3       361215.909741
# 4        11174.024633
#             ...
# 1333     83979.372491
# 1334      3636.630207
# 1335      1984.999633
# 1336      3012.906936
# 1337    634675.046322
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.376247
# 1         2224.247337
# 2        14793.342131
# 3       361211.232595
# 4        11172.832941
#             ...
# 1333     83976.257565
# 1334      3635.745448
# 1335      1984.231405
# 1336      3012.295401
# 1337    634669.226175
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.510984
# 1         2224.828484
# 2        14794.346075
# 3       361211.994661
# 4        11173.357607
#             ...
# 1333     83976.145939
# 1334      3636.427406
# 1335      1984.859488
# 1336      3012.676525
# 1337    634665.595664
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.305135
# 1         2224.548406
# 2        14793.943712
# 3       361211.945447
# 4        11173.139139
#             ...
# 1333     83976.571986
# 1334      3636.075228
# 1335      1984.542032
# 1336      3012.475712
# 1337    634667.961725
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.665352
# 1         2224.705285
# 2        14794.329177
# 3       361212.902906
# 4        11173.385184
#             ...
# 1333     83977.285310
# 1334      3636.269543
# 1335      1984.707672
# 1336      3012.612253
# 1337    634669.899771
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.609173
# 1         2224.804499
# 2        14794.586457
# 3       361213.795395
# 4        11173.576510
#             ...
# 1333     83977.854311
# 1334      3636.370281
# 1335      1984.800306
# 1336      3012.709279
# 1337    634671.155264
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.581965
# 1         2224.746856
# 2        14794.197599
# 3       361211.358473
# 4        11173.193065
#             ...
# 1333     83975.848659
# 1334      3636.294489
# 1335      1984.747931
# 1336      3012.582596
# 1337    634664.156485
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.795658
# 1         2224.884443
# 2        14795.198358
# 3       361218.785940
# 4        11174.339034
#             ...
# 1333     83981.585033
# 1334      3636.503714
# 1335      1984.869702
# 1336      3012.918555
# 1337    634684.794712
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.897885
# 1         2224.264499
# 2        14793.132883
# 3       361208.306245
# 4        11172.420004
#             ...
# 1333     83974.110997
# 1334      3635.705634
# 1335      1984.234790
# 1336      3012.184655
# 1337    634660.241780
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.493385
# 1         2224.462386
# 2        14793.663909
# 3       361210.827409
# 4        11172.923897
#             ...
# 1333     83975.720739
# 1334      3635.965458
# 1335      1984.453030
# 1336      3012.382755
# 1337    634665.528701
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.501905
# 1         2224.553287
# 2        14793.888868
# 3       361211.786189
# 4        11173.129236
#             ...
# 1333     83976.299827
# 1334      3636.084162
# 1335      1984.547659
# 1336      3012.479373
# 1337    634667.276215
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.902491
# 1         2224.703353
# 2        14794.385259
# 3       361214.548899
# 4        11173.631188
#             ...
# 1333     83978.210668
# 1334      3636.287900
# 1335      1984.700831
# 1336      3012.659747
# 1337    634673.706538
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.945656
# 1         2224.466964
# 2        14793.844066
# 3       361212.024261
# 4        11173.089582
#             ...
# 1333     83976.809632
# 1334      3635.976129
# 1335      1984.442312
# 1336      3012.449032
# 1337    634669.051656
# Name: charges, Length: 1338, dtype: float64
# {'R2': 0.12879024093954217, 'RMSE': 11299.092365712248, 'MAE': 9009.256548846519}

# %%
linreg_a = LinearRegression()

linreg_a.fit(X_encoded, y)

y_predict_a = linreg_a.predict(X_encoded)
evaluation_metrics_a = evaluate_regression(y, y_predict_a)
print(evaluation_metrics_a)

intercept_a = linreg_a.intercept_
coefficients_a = linreg_a.coef_
# Out:
# {'R2': 0.7509130345985207, 'RMSE': 6041.6796511744515, 'MAE': 4170.886894163588}

# %%
iter_space = list(range(10**3))

num_columns = 10
num_coeficients = 8

fig, axes = plt.subplots(num_columns, 1, figsize=(12, 4 * num_columns))
plt.subplots_adjust(hspace=0.3)

axes[0].plot(iter_space, mae, "-", label="MAE", color="green")
axes[0].set_title("Error Cuadrático Medio (MAE)")
axes[0].axhline(evaluation_metrics_a["RMSE"] ** 2, label="MAE de SkLearn", color="black")
axes[0].legend()
axes[0].grid()

axes[1].plot(iter_space, intercept_m, "-", label="Intercepto", color="blue")
axes[1].axhline(intercept_a, label="Intercepto de SkLearn", color="black")
axes[1].set_title("Intercepto")
axes[1].legend()
axes[1].grid()

for i in range(num_coeficients):
    subplot_index = i + 2
    coef_iter_values = [coefficients_m[j][i] for j in range(10**3)]
    axes[subplot_index].plot(iter_space, coef_iter_values, "-", label=f"Coeficiente x{i}")
    axes[subplot_index].axhline(coefficients_a[i], label=f"Coeficiente x{i} de SkLearn", color="black")
    axes[subplot_index].set_title(f"Coeficiente x{i}")
    axes[subplot_index].legend()
    axes[subplot_index].grid()

axes[-1].set_xlabel("Iteraciones")

plt.show()
