# %% [markdown]
# # Laboratory 2.4: Linear Regression contd.
#
# In this practice you will extend your Linear Regression code to a more general case. Here you will need the `synthetic_dataset.csv` present in the .zip file you downloaded alongside this notebook.
#
# In addition, we will be using the following libraries:
# - Data management:
#     - [numpy](https://numpy.org/)
#     - [pandas](https://pandas.pydata.org/)
#     - [scipy](https://scipy.org/)
# - Modelling:
#     - [scikit-learn](https://scikit-learn.org)
# - Plotting:
#     - [seaborn](https://seaborn.pydata.org/)
#     - [matplotlib](https://matplotlib.org/)
#
# ### **All the things you need to do are marked by a "TODO" comment nearby. Make sure you *read carefully everything before working* and solve each point before submitting your solution.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import os
import sys
# Get the absolute path of the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add it to sys.path
sys.path.insert(0, project_root)

# %% [markdown]
# ### Custom Linear Regression model

# %% [markdown]
# You are going to be working with the following class that you already know from the previous practice, so feel free to recycle as much code as you want (or can). In this case, you will be enhancing its functionalities, getting a more general function than the one you implemented before.
#
# **For now, just continue with the practice and do not fill anything, you will come back later to fill the gaps.**

# %%
from src.Lab_2_4_LR2 import LinearRegressor

# %% [markdown]
# **Data**: Remember, from the previous lab session, we had the following univariate dataset:

# %%
# Define data to use in this practice
x = np.array([0, 3, 2, 1, 4, 6, 7, 8, 9, 10])
y = np.array([2, 3, 2, 4, 5, 7, 9, 9, 10, 13])

# %% [markdown]
# Use the code *you wrote* from the previous practice (not the sklearn version) to fit the data in the following cell

# %%
linreg = LinearRegressor()
linreg.fit(x, y)

# %% [markdown]
# Before we get into the things you'll do today, let's construct a function that provides the values for the $R^2$, RMSE and MAE. For this, the inputs of this function are the true $y$ values and the predicted $\hat{y}$ values

# %%
from src.Lab_2_4_LR2 import evaluate_regression

# %%
# Obtain regression performance metrics
y_pred = linreg.predict(x)
evaluation_metrics = evaluate_regression(y, y_pred)
print(evaluation_metrics)
# Out:
# {'R2': 0.9201359388275276, 'RMSE': 1.0126472956832233, 'MAE': 0.8945454545454552}

# %% [markdown]
# ## Polynomial regression

# %% [markdown]
# In the previous practice, you have trained a model assuming that the relationship between input and output is linear. However, in most real cases this is not common and the relationship between input and output is not linear. In this section, we are going to learn how to deal with non-linear relationships when using linear models. Read `synthetic_dataset.csv` and train a linear regression model.
#
# *The target variable is the last column of the dataset*

# %%
data = pd.read_csv(f"{project_root}/data/synthetic_dataset.csv")

X = np.array(data[["Input1", "Input2", "Input3", "Input4"]])
y = np.array(data["Output"])

# %% [markdown]
# In this case we will skip the preprocessing and go straight to the modelling phase. Therefore, fit the model here.

# %%
linreg.fit(X, y, "gradient_descent")
y_pred = linreg.predict(X)
# Out:
# Epoch 0: MSE = [0.0045958  0.00088244 0.00500096 ... 0.00310881 0.0014702  0.0003792 ]

# %%
evaluate_regression(y, y_pred)
# Out:
# {'R2': 0.5452814220161836,
#  'RMSE': 3.1936452824804538,
#  'MAE': 2.2373493783947462}

# %% [markdown]
# If you trained the model well, the $R^2$ metric will be terrible, in the order of $0.5$. **What happened here?** Let's try to clear this via the *study of the residuals*.
#
# Create a function to plot the residuals of the model. This function shall:
# - Create a **histogram** of the residuals.
# - Create a **Q-Q plot** of the residuals.
# - Create a **scatterplot of the residuals against each input variable, the true output variable and the predictions**.
#
# **Why do we want to check the residuals this way?**
#
# > To see if all inputs are lineal

# %%
def plot_residuals(data, output_column, prediction_column):
    """
    Plot residuals of a model against all variables in the DataFrame, using box plots for
    categorical variables and scatter plots for continuous variables. Additionally, plot
    a histogram and a QQ-plot of the residuals.

    Args:
        data (pd.DataFrame): The DataFrame containing the data.
        output_column (str): The name of the output column.
        prediction_column (str): The name of the prediction column.
    """
    residuals = data[output_column] - data[prediction_column]
    
    num_features = len(data.columns) - 2  # Exclude output and prediction columns

    # Determine the number of rows and columns for subplots
    num_rows = int(np.ceil(np.sqrt(num_features + 4)))  # Add 4 for histogram, Q-Q plot, true output vs residuals, and predictions vs residuals
    num_cols = int(np.ceil((num_features + 4) / num_rows))

    # Plot histogram of residuals
    plt.figure(figsize=(5 * num_cols, 4 * num_rows))
    plt.subplot(num_rows, num_cols, 1)
    plt.hist(residuals, bins=30, edgecolor='black')
    plt.title('Histogram of Residuals')
    plt.xlabel('Residuals')
    plt.ylabel('Frequency')

    plt.subplot(num_rows, num_cols, 2)
    stats.probplot(residuals, dist="norm", plot=plt)      
    plt.title('Q-Q Plot of Residuals')

    plt.subplot(num_rows, num_cols, 3)
    plt.scatter(data[output_column], residuals, alpha=0.5)     
    plt.title('Residuals vs True Output')
    plt.xlabel('True Output')
    plt.ylabel('Residuals')

    # Plot residuals against prediction variable
    plt.subplot(num_rows, num_cols, 4)
    plt.scatter(data[prediction_column], residuals, alpha=0.5)   # Use this as example for later
    plt.title('Residuals vs Predictions')
    plt.xlabel('Predictions')
    plt.ylabel('Residuals')

    for i, col in enumerate(data.columns):
        if col not in [output_column, prediction_column]:
            plt.subplot(num_rows, num_cols, i + 5)
            plt.scatter(data[col], residuals, alpha=0.5)  
            plt.title(f'Residuals vs {col}')
            plt.xlabel(col)
            plt.ylabel('Residuals')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Now, **print the coefficients** of the model **alongside the plots** you can generate with the previous function

# %%
coef_dict = {'Input' + str(i+1): coef for i, coef in enumerate(linreg.coefficients)}
print(f"Coefficients of the model: {coef_dict}")  

# Plot the residuals for the predictions
data["Predictions"] = linreg.predict(X)
plot_residuals(data, 'Output', 'Predictions')
# Out:
# Coefficients of the model: {'Input1': -0.001939429757521296, 'Input2': -0.005934055855043521, 'Input3': 1.6302476384029914, 'Input4': 3.059196024521138}

# %% [markdown]
# **What are we seeing here? Is there any way to improve the model?**
# > Input1 is cuadratic and Input3 is exponential. We can modify the data in order to improve the model

# %% [markdown]
# As you may expect, you should see some higher-order contribution to the behavior of the data, since some of the residuals have clear structures. In particular, `Input1` has a higher-order polynomial contribution (*which order do you think?*), while `Input2` has an *exponential* form.
#
# In order to fit a regression model with these contributions, construct a new dataframe where each column corresponds to the desired manipulation of each variable. Then, fit the regression model and see the results.
#
# * Also, pay attention to the fact that you can use whatever contribution you see fit here, not just these previous ones.

# %%
data_transf = pd.DataFrame({'Input1': data["Input1"] ** 2,   # Substitute "None" by the degree you think works here
                            'Input2': np.exp(data["Input3"]),
                            'Input3': data["Input4"],
                            'Output': data["Output"]})
X_transf = data_transf.iloc[:,:3].values

# Train linear regression model
linreg = LinearRegressor()
linreg.fit(X_transf, y)

# Evaluate the metrics to see the behavior
y_pred = linreg.predict(X_transf)
evaluation_metrics = evaluate_regression(y, y_pred)
print(evaluation_metrics)
# Out:
# {'R2': 0.9557524745534756, 'RMSE': 0.9962304737909358, 'MAE': 0.7956340344398113}

# %% [markdown]
# Now, print again the coefficients for the model and plot the residuals as you did before.
#
# **What do you observe?**
# > This time R^2 is better

# %%
coef_dict = {'Input' + str(i+1): coef for i, coef in enumerate(linreg.coefficients)}
print(f"Coefficients of the model: {coef_dict}")
data_transf["Predictions"] = linreg.predict(X_transf)
plot_residuals(data_transf, 'Output', 'Predictions')
# Out:
# Coefficients of the model: {'Input1': 1.9985407741302759, 'Input2': 0.9951259300218519, 'Input3': 2.988069929362549}

# %% [markdown]
# ## Categorical variables

# %% [markdown]
# Linear regression, as is, can not deal with categorical variables. Therefore, we need to encode the variables when preprocessing the data. Complete the one-hot-encode function below. Take into account that strings shall be treated automatically as categorical variables.
# <center>
#
# ![Image](https://miro.medium.com/v2/resize:fit:1358/1*ggtP4a5YaRx6l09KQaYOnw.png)
#
# </center>

# %%
from src.Lab_2_4_LR2 import one_hot_encode

# %% [markdown]
# We will use this in a usual dataset from the internet. If everything is well, you should be able to run the following code as-is.

# %%
# Load the dataset
url = "https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv"
data = pd.read_csv(url)


y = data['charges'].values
X = data.drop(columns=['charges']).values

# Preprocess the data
# Identify categorical columns for one-hot encoding
categorical_columns = [data.columns.get_loc(col) for col in ['sex', 'smoker', 'region']]

# One-hot encode categorical variables
X_encoded = one_hot_encode(X, categorical_columns, drop_first=True)
X_encoded = X_encoded.astype(float)                                  # Watch out for this!

# Instantiate and fit the LinearRegressor
model = LinearRegressor()
model.fit(X_encoded, y)

# Predict and evaluate
y_pred = model.predict(X_encoded)
evaluation_metrics = evaluate_regression(y, y_pred)
print(evaluation_metrics)
# Out:
# {'R2': 0.7509130345985207, 'RMSE': 6041.6796511744515, 'MAE': 4170.886894163565}

# %% [markdown]
# Compare yourself with scikit

# %%
from sklearn.linear_model import LinearRegression

# Load the dataset
url = "https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv"
data = pd.read_csv(url)

# Preprocess the data
data_encoded = pd.get_dummies(data) 

# Split the data into features (X) and target (y)
X = data_encoded.drop('charges', axis=1)
y = data_encoded['charges']

# Instantiate the LinearRegression model
model = LinearRegression()

# Fit the model on the training data
model.fit(X, y)

# Make predictions on the test data
y_pred = model.predict(X)

# Evaluate the model
evaluation_metrics = evaluate_regression(y, y_pred)
print(evaluation_metrics)
# Out:
# {'R2': 0.7509130345985207, 'RMSE': 6041.6796511744515, 'MAE': 4170.886894163589}

# %% [markdown]
# ### Colored residuals

# %% [markdown]
# Now that we have categorical variables, the relationship between inputs and outputs might differ for different levels of the categorical variables. Therefore, you will modify the `plot_residuals` function to **color the scatter plots based on the value of a specific categorical variable**.

# %%
def plot_residuals(data, output_column, prediction_column, categorical_var=None):
    """
    Plot residuals of a model against all variables in the DataFrame. Additionally, plot
    a histogram and a QQ-plot of the residuals.

    Args:
        data (pd.DataFrame): The DataFrame containing the data.
        output_column (str): The name of the output column.
        prediction_column (str): The name of the prediction column.
        categorical_var (str, optional): The name of a categorical variable for coloring. Defaults to None.
    """
    data['residuals'] = data[output_column] - data[prediction_column]

    # Identify columns to plot (excluding the output and prediction columns)
    columns_to_plot = [col for col in data.columns if col not in [output_column, prediction_column, 'residuals']]

    # Number of rows and columns for the subplot
    n_cols = 3
    n_rows = int(len(columns_to_plot) / n_cols) + 2  # Additional row for histogram and QQ-plot

    # Create subplots
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 5))

    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    for i, col in enumerate(columns_to_plot):
        ax = axes[i]
        
        if categorical_var and categorical_var in data.columns:
            sns.scatterplot(x = data[col], y = data[output_column], data=data, ax=ax, hue = data[categorical_var])
        else:
            sns.scatterplot(x = data[col], y = data[output_column], data=data, ax=ax)
        
        ax.set_title(f'Residuals vs {col}')
        ax.axhline(0, ls='--', color='r')

    # Histogram of residuals
    sns.histplot(data['residuals'], kde=True, ax=axes[i + 1])
    axes[i + 1].set_title('Histogram of Residuals')

    # QQ-plot of residuals
    stats.probplot(data['residuals'], dist="norm", plot=axes[i + 2])
    axes[i + 2].set_title('QQ-Plot of Residuals')

    # Hide any unused axes
    for j in range(i + 3, len(axes)):
        axes[j].set_visible(False)

    plt.tight_layout()
    plt.show()

data['predictions'] = model.predict(X)
# Example usage
plot_residuals(data, 'charges', 'predictions', 'smoker')

# %% [markdown]
# **What's happening with the residuals?**
# > There is a relationship between the inputs and the fact that the person smokes

# %% [markdown]
# # _Rolling in the deep_

# %% [markdown]
# Following the theory taught in class, do the following:
#
# 1. **implement the gradient descent algorithm** to train the linear regression model and reproduce the results using this training method. You can find the structure for the gradient descent inside the initial linear regression function, inside the method `fit_gradient_descent`.
# 2. As final steps, **display the progress of the loss function by plotting the gradient descent steps on the X-axis and the loss function on the Y-axis for each step**.
# 3. Additionally, **using the same representation as in the previous section where each axis represents the values of w and b, show the sequence of steps that bring you closer to the optimum each time**. Each step should be a point in space, with coordinates (w,b). Compare all the results with the optimal solution from the scikit fit coefficients.
#
# Feel free to add as many cells as you may need from here onwards in order to fulfill these three tasks

# %%
linreg_m = LinearRegressor()

mae = []
intercept_m = []
coefficients_m = []
for i in range(1, 10**3 + 1):
    linreg_m.fit(X_encoded, y, method="gradient_descent", learning_rate=0.0001, iterations=i)
    y_pred_m = linreg_m.predict(X_encoded)
    evaluation_metrics_m = evaluate_regression(y, y_pred_m)
    mae.append(evaluation_metrics_m["MAE"])
    intercept_m.append(linreg_m.intercept)
    coefficients_m.append(linreg_m.coefficients)

print(evaluation_metrics_m)
# Out:
# Epoch 0: MSE = 0       213076.058040
# 1         2224.881850
# 2        14795.282051
# 3       361219.095039
# 4        11174.381670
#             ...
# 1333     83982.029033
# 1334      3636.497657
# 1335      1984.850003
# 1336      3012.932549
# 1337    634685.833192
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.176252
# 1         2224.398583
# 2        14793.386533
# 3       361209.352116
# 4        11172.680289
#             ...
# 1333     83974.595156
# 1334      3635.911528
# 1335      1984.410387
# 1336      3012.314093
# 1337    634662.476127
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.559879
# 1         2224.835054
# 2        14794.899492
# 3       361217.498024
# 4        11174.142252
#             ...
# 1333     83980.368782
# 1334      3636.461532
# 1335      1984.825917
# 1336      3012.858331
# 1337    634680.999786
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.541408
# 1         2225.026114
# 2        14795.125951
# 3       361216.342994
# 4        11174.098884
#             ...
# 1333     83979.320882
# 1334      3636.655627
# 1335      1985.027936
# 1336      3012.929073
# 1337    634675.864033
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.918135
# 1         2224.825078
# 2        14794.819306
# 3       361216.622366
# 4        11173.997198
#             ...
# 1333     83979.736370
# 1334      3636.405553
# 1335      1984.806172
# 1336      3012.778241
# 1337    634678.503824
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.624094
# 1         2224.188354
# 2        14792.847432
# 3       361207.246328
# 4        11172.237846
#             ...
# 1333     83973.262581
# 1334      3635.648226
# 1335      1984.184252
# 1336      3012.137401
# 1337    634658.424633
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.029502
# 1         2224.283755
# 2        14793.097303
# 3       361208.747754
# 4        11172.514592
#             ...
# 1333     83974.088491
# 1334      3635.752604
# 1335      1984.269318
# 1336      3012.206691
# 1337    634660.748435
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.062682
# 1         2224.756881
# 2        14794.309706
# 3       361211.767189
# 4        11173.265213
#             ...
# 1333     83976.368955
# 1334      3636.316115
# 1335      1984.759314
# 1336      3012.619260
# 1337    634665.586047
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.141030
# 1         2224.868578
# 2        14794.851806
# 3       361215.147308
# 4        11173.811181
#             ...
# 1333     83978.926367
# 1334      3636.465924
# 1335      1984.868442
# 1336      3012.790348
# 1337    634674.631842
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.412503
# 1         2224.483405
# 2        14794.144659
# 3       361214.659160
# 4        11173.474353
#             ...
# 1333     83978.880065
# 1334      3636.010085
# 1335      1984.437049
# 1336      3012.516647
# 1337    634676.751370
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.793419
# 1         2224.227055
# 2        14792.923303
# 3       361207.006870
# 4        11172.220518
#             ...
# 1333     83973.137930
# 1334      3635.688212
# 1335      1984.227822
# 1336      3012.152033
# 1337    634657.743703
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.595943
# 1         2224.903150
# 2        14795.252928
# 3       361218.631131
# 4        11174.311781
#             ...
# 1333     83981.500949
# 1334      3636.486044
# 1335      1984.858389
# 1336      3012.888239
# 1337    634683.557944
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.455173
# 1         2224.721439
# 2        14794.682701
# 3       361216.511734
# 4        11173.907833
#             ...
# 1333     83979.915212
# 1334      3636.301383
# 1335      1984.692610
# 1336      3012.747207
# 1337    634679.156838
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.305548
# 1         2224.871435
# 2        14794.846005
# 3       361216.205514
# 4        11173.970835
#             ...
# 1333     83979.333520
# 1334      3636.469972
# 1335      1984.867977
# 1336      3012.819754
# 1337    634676.817461
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.154133
# 1         2224.129690
# 2        14792.703560
# 3       361207.269296
# 4        11172.201849
#             ...
# 1333     83973.157669
# 1334      3635.578945
# 1335      1984.117295
# 1336      3012.095938
# 1337    634658.478098
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.080381
# 1         2224.740331
# 2        14794.335529
# 3       361213.568791
# 4        11173.527733
#             ...
# 1333     83977.409956
# 1334      3636.341360
# 1335      1984.761898
# 1336      3012.663269
# 1337    634670.860092
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.078926
# 1         2224.503986
# 2        14793.616072
# 3       361210.140635
# 4        11172.865983
#             ...
# 1333     83975.006489
# 1334      3636.033572
# 1335      1984.516098
# 1336      3012.425742
# 1337    634663.236912
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.242470
# 1         2224.861613
# 2        14794.916459
# 3       361215.940754
# 4        11173.916423
#             ...
# 1333     83979.524560
# 1334      3636.442576
# 1335      1984.835371
# 1336      3012.799310
# 1337    634676.717373
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.622410
# 1         2224.542991
# 2        14794.211474
# 3       361213.978841
# 4        11173.408204
#             ...
# 1333     83978.377807
# 1334      3636.057867
# 1335      1984.501359
# 1336      3012.531624
# 1337    634674.230735
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.028849
# 1         2224.354978
# 2        14793.435872
# 3       361210.304630
# 4        11172.769184
#             ...
# 1333     83975.421972
# 1334      3635.854250
# 1335      1984.349825
# 1336      3012.339132
# 1337    634665.480676
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.078436
# 1         2224.408745
# 2        14793.358815
# 3       361209.067209
# 4        11172.647273
#             ...
# 1333     83974.295731
# 1334      3635.900331
# 1335      1984.410845
# 1336      3012.292699
# 1337    634661.129022
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.277344
# 1         2224.833378
# 2        14795.091754
# 3       361218.396048
# 4        11174.245211
#             ...
# 1333     83981.373165
# 1334      3636.422255
# 1335      1984.796729
# 1336      3012.849724
# 1337    634683.817819
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.532627
# 1         2224.656372
# 2        14794.340746
# 3       361214.415005
# 4        11173.570096
#             ...
# 1333     83978.296887
# 1334      3636.215569
# 1335      1984.638243
# 1336      3012.627989
# 1337    634673.872506
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.523495
# 1         2224.203126
# 2        14792.951368
# 3       361207.301314
# 4        11172.250415
#             ...
# 1333     83973.544439
# 1334      3635.669081
# 1335      1984.194278
# 1336      3012.137810
# 1337    634658.624999
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.046171
# 1         2224.851563
# 2        14794.617604
# 3       361213.802746
# 4        11173.630485
#             ...
# 1333     83977.708210
# 1334      3636.464292
# 1335      1984.866797
# 1336      3012.745667
# 1337    634670.654007
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.469515
# 1         2225.101235
# 2        14795.582499
# 3       361219.224707
# 4        11174.566539
#             ...
# 1333     83981.673571
# 1334      3636.778468
# 1335      1985.106451
# 1336      3013.078552
# 1337    634683.735282
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.872703
# 1         2224.285836
# 2        14793.188934
# 3       361208.301849
# 4        11172.432134
#             ...
# 1333     83974.159722
# 1334      3635.730913
# 1335      1984.258353
# 1336      3012.186337
# 1337    634660.123705
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.428929
# 1         2224.409436
# 2        14793.521450
# 3       361210.294855
# 4        11172.830110
#             ...
# 1333     83975.423368
# 1334      3635.931475
# 1335      1984.408026
# 1336      3012.369126
# 1337    634664.606126
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.031466
# 1         2224.279931
# 2        14793.183808
# 3       361209.126916
# 4        11172.550312
#             ...
# 1333     83974.546706
# 1334      3635.743134
# 1335      1984.266459
# 1336      3012.221073
# 1337    634662.506680
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.846985
# 1         2224.707243
# 2        14794.185685
# 3       361212.713849
# 4        11173.384249
#             ...
# 1333     83976.733674
# 1334      3636.294991
# 1335      1984.720438
# 1336      3012.627161
# 1337    634668.241289
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.768863
# 1         2224.536592
# 2        14794.136451
# 3       361214.197668
# 4        11173.452650
#             ...
# 1333     83978.314922
# 1334      3636.086050
# 1335      1984.517948
# 1336      3012.556289
# 1337    634674.951657
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.515148
# 1         2225.092000
# 2        14795.597581
# 3       361220.259369
# 4        11174.720424
#             ...
# 1333     83982.257970
# 1334      3636.779467
# 1335      1985.093980
# 1336      3013.085164
# 1337    634686.356774
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.676721
# 1         2224.124603
# 2        14792.695934
# 3       361205.723435
# 4        11171.954696
#             ...
# 1333     83972.461598
# 1334      3635.541704
# 1335      1984.112442
# 1336      3012.027448
# 1337    634655.211840
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.930909
# 1         2224.985557
# 2        14795.087876
# 3       361215.917747
# 4        11174.007121
#             ...
# 1333     83979.274903
# 1334      3636.587457
# 1335      1984.980178
# 1336      3012.873865
# 1337    634674.913692
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.775760
# 1         2224.415518
# 2        14793.876795
# 3       361213.935903
# 4        11173.326749
#             ...
# 1333     83978.098516
# 1334      3635.929304
# 1335      1984.379734
# 1336      3012.467987
# 1337    634674.865864
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.054789
# 1         2225.076009
# 2        14795.511453
# 3       361218.818654
# 4        11174.477131
#             ...
# 1333     83981.373749
# 1334      3636.714144
# 1335      1985.067982
# 1336      3013.023492
# 1337    634682.819396
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.516367
# 1         2224.700795
# 2        14794.043813
# 3       361210.875666
# 4        11173.109129
#             ...
# 1333     83975.484165
# 1334      3636.266493
# 1335      1984.715768
# 1336      3012.552746
# 1337    634663.716105
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.870236
# 1         2224.934335
# 2        14795.280581
# 3       361218.684993
# 4        11174.352824
#             ...
# 1333     83981.453237
# 1334      3636.529700
# 1335      1984.900678
# 1336      3012.907282
# 1337    634683.605878
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.766203
# 1         2224.511600
# 2        14793.620384
# 3       361209.692271
# 4        11172.803296
#             ...
# 1333     83974.768739
# 1334      3636.027587
# 1335      1984.518407
# 1336      3012.384129
# 1337    634661.922382
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.053059
# 1         2224.149788
# 2        14792.793563
# 3       361207.106148
# 4        11172.169800
#             ...
# 1333     83973.200698
# 1334      3635.580436
# 1335      1984.137008
# 1336      3012.097769
# 1337    634658.178849
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.502569
# 1         2224.825261
# 2        14794.992218
# 3       361218.559001
# 4        11174.283910
#             ...
# 1333     83981.208417
# 1334      3636.447239
# 1335      1984.809283
# 1336      3012.863131
# 1337    634684.264988
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.380461
# 1         2224.502239
# 2        14793.831759
# 3       361212.399912
# 4        11173.182236
#             ...
# 1333     83976.726799
# 1334      3636.046510
# 1335      1984.501343
# 1336      3012.496401
# 1337    634669.665798
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.034496
# 1         2224.240078
# 2        14792.902649
# 3       361207.540340
# 4        11172.325282
#             ...
# 1333     83973.248121
# 1334      3635.727217
# 1335      1984.250992
# 1336      3012.180383
# 1337    634658.513923
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.020332
# 1         2224.761715
# 2        14794.411150
# 3       361212.248065
# 4        11173.321679
#             ...
# 1333     83976.870863
# 1334      3636.316598
# 1335      1984.762118
# 1336      3012.629490
# 1337    634667.578884
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.455442
# 1         2224.541810
# 2        14793.750564
# 3       361210.521215
# 4        11172.955847
#             ...
# 1333     83975.413395
# 1334      3636.091043
# 1335      1984.552022
# 1336      3012.446362
# 1337    634664.170866
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.278801
# 1         2224.651375
# 2        14794.140532
# 3       361212.695891
# 4        11173.337344
#             ...
# 1333     83976.944674
# 1334      3636.221746
# 1335      1984.659501
# 1336      3012.575426
# 1337    634669.048939
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.075385
# 1         2225.012891
# 2        14795.152027
# 3       361215.722168
# 4        11173.991606
#             ...
# 1333     83979.207074
# 1334      3636.603130
# 1335      1984.994135
# 1336      3012.866856
# 1337    634674.220783
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.714250
# 1         2224.740164
# 2        14794.390270
# 3       361213.022142
# 4        11173.425324
#             ...
# 1333     83977.283321
# 1334      3636.278104
# 1335      1984.722174
# 1336      3012.623151
# 1337    634668.876910
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.744083
# 1         2224.107483
# 2        14792.589448
# 3       361206.401849
# 4        11172.060460
#             ...
# 1333     83972.544980
# 1334      3635.549488
# 1335      1984.097291
# 1336      3012.047590
# 1337    634656.426530
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.342422
# 1         2224.983952
# 2        14795.165853
# 3       361217.346250
# 4        11174.214977
#             ...
# 1333     83980.188348
# 1334      3636.605014
# 1335      1984.973819
# 1336      3012.929939
# 1337    634679.021712
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.430828
# 1         2224.515297
# 2        14794.131259
# 3       361213.712065
# 4        11173.351731
#             ...
# 1333     83978.175771
# 1334      3636.033528
# 1335      1984.487679
# 1336      3012.513802
# 1337    634673.941487
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.788638
# 1         2224.403780
# 2        14793.599144
# 3       361211.292400
# 4        11172.961228
#             ...
# 1333     83976.139071
# 1334      3635.937240
# 1335      1984.401361
# 1336      3012.409318
# 1337    634667.937861
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.742007
# 1         2224.630438
# 2        14794.048577
# 3       361211.142336
# 4        11173.075655
#             ...
# 1333     83976.021372
# 1334      3636.148444
# 1335      1984.610586
# 1336      3012.505649
# 1337    634664.742542
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.602066
# 1         2224.217715
# 2        14792.905808
# 3       361207.719544
# 4        11172.319417
#             ...
# 1333     83973.441813
# 1334      3635.677074
# 1335      1984.221119
# 1336      3012.143318
# 1337    634659.424514
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.639362
# 1         2224.575200
# 2        14793.937282
# 3       361211.595743
# 4        11173.105487
#             ...
# 1333     83976.219142
# 1334      3636.095800
# 1335      1984.565110
# 1336      3012.493417
# 1337    634666.977808
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.583625
# 1         2224.786263
# 2        14794.831836
# 3       361216.321805
# 4        11173.916707
#             ...
# 1333     83979.894007
# 1334      3636.359940
# 1335      1984.758529
# 1336      3012.763506
# 1337    634678.169043
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.982499
# 1         2224.467194
# 2        14793.727289
# 3       361210.965368
# 4        11172.942920
#             ...
# 1333     83975.960350
# 1334      3635.972996
# 1335      1984.446656
# 1336      3012.414923
# 1337    634666.302913
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.674984
# 1         2225.218897
# 2        14795.971558
# 3       361221.029784
# 4        11174.892715
#             ...
# 1333     83982.957271
# 1334      3636.912885
# 1335      1985.212940
# 1336      3013.209707
# 1337    634687.915307
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.844629
# 1         2224.350807
# 2        14793.275505
# 3       361208.033773
# 4        11172.447492
#             ...
# 1333     83973.936369
# 1334      3635.835259
# 1335      1984.346922
# 1336      3012.262671
# 1337    634659.377242
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.361822
# 1         2224.296769
# 2        14793.260625
# 3       361209.432408
# 4        11172.603845
#             ...
# 1333     83974.838478
# 1334      3635.764487
# 1335      1984.282972
# 1336      3012.256647
# 1337    634663.596341
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.283569
# 1         2224.510167
# 2        14793.995836
# 3       361212.696536
# 4        11173.207906
#             ...
# 1333     83977.303021
# 1334      3636.016095
# 1335      1984.484589
# 1336      3012.471871
# 1337    634670.838548
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.651252
# 1         2224.311739
# 2        14793.485695
# 3       361210.968937
# 4        11172.837824
#             ...
# 1333     83976.196815
# 1334      3635.811890
# 1335      1984.291539
# 1336      3012.313186
# 1337    634667.776233
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.278667
# 1         2225.102905
# 2        14795.521850
# 3       361218.572168
# 4        11174.473487
#             ...
# 1333     83981.144063
# 1334      3636.741431
# 1335      1985.084919
# 1336      3013.028069
# 1337    634681.240492
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.826534
# 1         2224.269096
# 2        14793.085589
# 3       361207.887717
# 4        11172.382997
#             ...
# 1333     83973.800412
# 1334      3635.725314
# 1335      1984.247009
# 1336      3012.162295
# 1337    634658.912029
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.359059
# 1         2224.368405
# 2        14793.655898
# 3       361212.179536
# 4        11173.047984
#             ...
# 1333     83976.902566
# 1334      3635.870876
# 1335      1984.335255
# 1336      3012.373561
# 1337    634670.560635
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.276992
# 1         2224.060852
# 2        14792.482329
# 3       361205.578275
# 4        11171.899700
#             ...
# 1333     83972.091122
# 1334      3635.475030
# 1335      1984.044909
# 1336      3011.975693
# 1337    634654.704221
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.110426
# 1         2224.227426
# 2        14793.135121
# 3       361209.467975
# 4        11172.567513
#             ...
# 1333     83974.917702
# 1334      3635.705410
# 1335      1984.224418
# 1336      3012.220230
# 1337    634664.932433
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.767791
# 1         2224.582348
# 2        14793.951138
# 3       361211.476579
# 4        11173.115970
#             ...
# 1333     83976.242569
# 1334      3636.136494
# 1335      1984.585170
# 1336      3012.506330
# 1337    634666.462771
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.722333
# 1         2224.229174
# 2        14792.994403
# 3       361207.971360
# 4        11172.369781
#             ...
# 1333     83973.816754
# 1334      3635.709443
# 1335      1984.228681
# 1336      3012.166890
# 1337    634660.107232
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.679430
# 1         2224.226003
# 2        14793.094171
# 3       361208.347756
# 4        11172.397752
#             ...
# 1333     83974.268787
# 1334      3635.678086
# 1335      1984.206315
# 1336      3012.165833
# 1337    634661.360374
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.291428
# 1         2225.120112
# 2        14795.659338
# 3       361219.264925
# 4        11174.564745
#             ...
# 1333     83981.749589
# 1334      3636.764994
# 1335      1985.100650
# 1336      3013.061641
# 1337    634683.242862
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.223818
# 1         2224.915667
# 2        14795.310638
# 3       361219.325047
# 4        11174.437528
#             ...
# 1333     83981.969463
# 1334      3636.527502
# 1335      1984.874136
# 1336      3012.947782
# 1337    634685.400732
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.185566
# 1         2224.162686
# 2        14792.774815
# 3       361206.432114
# 4        11172.101158
#             ...
# 1333     83972.823989
# 1334      3635.603197
# 1335      1984.152771
# 1336      3012.085262
# 1337    634656.217175
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.499863
# 1         2224.486755
# 2        14794.180910
# 3       361215.396950
# 4        11173.585640
#             ...
# 1333     83979.304286
# 1334      3636.036975
# 1335      1984.462552
# 1336      3012.557278
# 1337    634678.671561
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.718369
# 1         2224.584154
# 2        14793.882636
# 3       361210.528327
# 4        11172.963237
#             ...
# 1333     83975.521137
# 1334      3636.107064
# 1335      1984.580585
# 1336      3012.475567
# 1337    634664.031116
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.754489
# 1         2224.637120
# 2        14794.006366
# 3       361210.834964
# 4        11173.044345
#             ...
# 1333     83975.716063
# 1334      3636.153597
# 1335      1984.631136
# 1336      3012.494483
# 1337    634663.838264
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.988205
# 1         2224.254657
# 2        14793.214985
# 3       361209.166636
# 4        11172.532151
#             ...
# 1333     83974.828572
# 1334      3635.705329
# 1335      1984.229067
# 1336      3012.196102
# 1337    634663.335972
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.475674
# 1         2224.965819
# 2        14795.356027
# 3       361220.112678
# 4        11174.595680
#             ...
# 1333     83982.149276
# 1334      3636.603916
# 1335      1984.947160
# 1336      3012.989042
# 1337    634686.855628
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.723001
# 1         2224.671654
# 2        14794.290771
# 3       361214.041656
# 4        11173.532621
#             ...
# 1333     83977.875238
# 1334      3636.237043
# 1335      1984.673796
# 1336      3012.635791
# 1337    634672.942503
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.556437
# 1         2224.258014
# 2        14793.292444
# 3       361210.875084
# 4        11172.794844
#             ...
# 1333     83975.867059
# 1334      3635.740800
# 1335      1984.239408
# 1336      3012.286505
# 1337    634668.048060
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.983488
# 1         2225.301061
# 2        14796.277674
# 3       361222.441347
# 4        11175.137458
#             ...
# 1333     83984.023943
# 1334      3636.981106
# 1335      1985.274724
# 1336      3013.265912
# 1337    634690.782711
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.834022
# 1         2224.501682
# 2        14793.725549
# 3       361210.404410
# 4        11172.887145
#             ...
# 1333     83975.475765
# 1334      3636.003426
# 1335      1984.489105
# 1336      3012.410490
# 1337    634663.962887
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.355233
# 1         2224.951434
# 2        14795.188637
# 3       361217.691714
# 4        11174.246100
#             ...
# 1333     83980.661571
# 1334      3636.591157
# 1335      1984.941960
# 1336      3012.942028
# 1337    634680.573096
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.166766
# 1         2224.661144
# 2        14794.165700
# 3       361212.109455
# 4        11173.239881
#             ...
# 1333     83976.647302
# 1334      3636.198835
# 1335      1984.647533
# 1336      3012.555446
# 1337    634667.246290
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.781772
# 1         2225.150756
# 2        14795.726309
# 3       361220.398057
# 4        11174.766201
#             ...
# 1333     83982.320636
# 1334      3636.828364
# 1335      1985.153517
# 1336      3013.119969
# 1337    634686.293614
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.191865
# 1         2224.463047
# 2        14794.175931
# 3       361215.385443
# 4        11173.556412
#             ...
# 1333     83979.410215
# 1334      3635.969707
# 1335      1984.416283
# 1336      3012.515692
# 1337    634678.916340
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.588074
# 1         2224.856203
# 2        14795.068880
# 3       361218.658656
# 4        11174.302753
#             ...
# 1333     83981.252086
# 1334      3636.470267
# 1335      1984.839029
# 1336      3012.879284
# 1337    634684.337379
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.022846
# 1         2224.954681
# 2        14795.130923
# 3       361216.900039
# 4        11174.127285
#             ...
# 1333     83980.078769
# 1334      3636.581097
# 1335      1984.946839
# 1336      3012.887486
# 1337    634678.605703
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.556736
# 1         2224.564343
# 2        14793.861146
# 3       361211.199260
# 4        11173.057272
#             ...
# 1333     83975.914807
# 1334      3636.110896
# 1335      1984.569658
# 1336      3012.486199
# 1337    634665.949830
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.284808
# 1         2224.578869
# 2        14794.300624
# 3       361215.785162
# 4        11173.717841
#             ...
# 1333     83979.294799
# 1334      3636.143735
# 1335      1984.564780
# 1336      3012.618763
# 1337    634678.812648
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.780574
# 1         2224.819903
# 2        14794.845149
# 3       361216.086762
# 4        11173.915847
#             ...
# 1333     83979.644561
# 1334      3636.401891
# 1335      1984.803747
# 1336      3012.762692
# 1337    634677.440565
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.233421
# 1         2224.481216
# 2        14793.802093
# 3       361211.872338
# 4        11173.087501
#             ...
# 1333     83976.529610
# 1334      3636.003143
# 1335      1984.459001
# 1336      3012.459782
# 1337    634668.477683
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.488510
# 1         2224.473798
# 2        14794.177555
# 3       361215.720717
# 4        11173.617672
#             ...
# 1333     83979.504240
# 1334      3635.998635
# 1335      1984.431341
# 1336      3012.545491
# 1337    634679.763111
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.172157
# 1         2224.220483
# 2        14793.133548
# 3       361209.894326
# 4        11172.627273
#             ...
# 1333     83975.140511
# 1334      3635.702980
# 1335      1984.205807
# 1336      3012.244857
# 1337    634665.499093
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.054304
# 1         2224.418239
# 2        14793.327431
# 3       361208.624520
# 4        11172.588139
#             ...
# 1333     83973.937748
# 1334      3635.911393
# 1335      1984.428159
# 1336      3012.294685
# 1337    634660.017422
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.931365
# 1         2224.717500
# 2        14794.672637
# 3       361215.892916
# 4        11173.805013
#             ...
# 1333     83979.625740
# 1334      3636.267114
# 1335      1984.682930
# 1336      3012.693549
# 1337    634677.789836
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.681852
# 1         2224.589325
# 2        14794.022076
# 3       361211.699498
# 4        11173.132341
#             ...
# 1333     83976.466879
# 1334      3636.121281
# 1335      1984.584761
# 1336      3012.506763
# 1337    634667.063287
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.456531
# 1         2224.759112
# 2        14794.573863
# 3       361215.350094
# 4        11173.772205
#             ...
# 1333     83978.802203
# 1334      3636.335444
# 1335      1984.753998
# 1336      3012.727009
# 1337    634675.783345
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.694801
# 1         2224.854348
# 2        14795.054039
# 3       361218.490142
# 4        11174.286253
#             ...
# 1333     83981.161580
# 1334      3636.474629
# 1335      1984.828102
# 1336      3012.898814
# 1337    634683.286509
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.455542
# 1         2224.945792
# 2        14795.321892
# 3       361218.902975
# 4        11174.406769
#             ...
# 1333     83981.666371
# 1334      3636.577598
# 1335      1984.922193
# 1336      3012.968724
# 1337    634684.287026
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.512354
# 1         2224.470547
# 2        14794.122288
# 3       361215.086788
# 4        11173.524165
#             ...
# 1333     83979.055236
# 1334      3636.004805
# 1335      1984.434130
# 1336      3012.549128
# 1337    634677.892250
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.725292
# 1         2224.953538
# 2        14794.834034
# 3       361214.881522
# 4        11173.851550
#             ...
# 1333     83978.205554
# 1334      3636.570744
# 1335      1984.973015
# 1336      3012.818745
# 1337    634672.525455
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.939164
# 1         2224.903738
# 2        14794.748442
# 3       361213.465820
# 4        11173.599496
#             ...
# 1333     83977.608631
# 1334      3636.478257
# 1335      1984.904832
# 1336      3012.736279
# 1337    634669.170702
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.502584
# 1         2224.723856
# 2        14794.165151
# 3       361211.438927
# 4        11173.191890
#             ...
# 1333     83975.937275
# 1334      3636.269606
# 1335      1984.728386
# 1336      3012.566026
# 1337    634664.817030
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.953036
# 1         2224.586436
# 2        14794.397179
# 3       361215.174801
# 4        11173.616125
#             ...
# 1333     83979.270096
# 1334      3636.123716
# 1335      1984.544437
# 1336      3012.593593
# 1337    634676.991036
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.444903
# 1         2224.428648
# 2        14793.443901
# 3       361209.357587
# 4        11172.701685
#             ...
# 1333     83974.577648
# 1334      3635.934004
# 1335      1984.432157
# 1336      3012.348497
# 1337    634661.641785
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.324850
# 1         2224.961487
# 2        14795.430587
# 3       361219.191369
# 4        11174.439852
#             ...
# 1333     83982.011958
# 1334      3636.580545
# 1335      1984.933060
# 1336      3012.979388
# 1337    634685.126611
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.988186
# 1         2224.322791
# 2        14793.626218
# 3       361212.050558
# 4        11172.988656
#             ...
# 1333     83977.041857
# 1334      3635.808786
# 1335      1984.291093
# 1336      3012.360223
# 1337    634670.937183
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.384585
# 1         2224.897159
# 2        14795.203754
# 3       361219.574055
# 4        11174.474335
#             ...
# 1333     83981.874596
# 1334      3636.552156
# 1335      1984.886938
# 1336      3012.977407
# 1337    634686.418916
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.415296
# 1         2224.422384
# 2        14793.565393
# 3       361210.229021
# 4        11172.819760
#             ...
# 1333     83975.426321
# 1334      3635.945043
# 1335      1984.419685
# 1336      3012.362228
# 1337    634664.461687
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.410796
# 1         2224.537841
# 2        14794.015977
# 3       361212.975446
# 4        11173.284266
#             ...
# 1333     83977.363459
# 1334      3636.067868
# 1335      1984.524211
# 1336      3012.495770
# 1337    634671.104809
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.959825
# 1         2224.501229
# 2        14794.207791
# 3       361215.841582
# 4        11173.662746
#             ...
# 1333     83979.493473
# 1334      3636.052456
# 1335      1984.476572
# 1336      3012.597648
# 1337    634679.767859
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.757432
# 1         2224.333786
# 2        14793.261949
# 3       361209.380531
# 4        11172.639986
#             ...
# 1333     83974.597605
# 1334      3635.825111
# 1335      1984.324839
# 1336      3012.280514
# 1337    634662.412356
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.017390
# 1         2224.973433
# 2        14794.954127
# 3       361215.493979
# 4        11173.949923
#             ...
# 1333     83978.763614
# 1334      3636.607781
# 1335      1984.999564
# 1336      3012.873842
# 1337    634674.490596
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.635449
# 1         2224.634418
# 2        14794.426357
# 3       361215.796379
# 4        11173.750565
#             ...
# 1333     83979.337100
# 1334      3636.208112
# 1335      1984.626298
# 1336      3012.656566
# 1337    634678.474209
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.295445
# 1         2225.025232
# 2        14795.120965
# 3       361216.707787
# 4        11174.157338
#             ...
# 1333     83979.482270
# 1334      3636.649871
# 1335      1985.030089
# 1336      3012.908942
# 1337    634676.624057
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.025663
# 1         2225.178559
# 2        14795.909294
# 3       361220.640192
# 4        11174.792664
#             ...
# 1333     83982.786828
# 1334      3636.830957
# 1335      1985.149926
# 1336      3013.153069
# 1337    634686.732019
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.943830
# 1         2224.349601
# 2        14793.428249
# 3       361210.666258
# 4        11172.826686
#             ...
# 1333     83975.612762
# 1334      3635.852725
# 1335      1984.349810
# 1336      3012.330931
# 1337    634666.417913
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.613018
# 1         2224.651362
# 2        14794.336385
# 3       361214.191209
# 4        11173.543110
#             ...
# 1333     83978.255689
# 1334      3636.219619
# 1335      1984.644747
# 1336      3012.635696
# 1337    634673.547564
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.268788
# 1         2224.324960
# 2        14793.214551
# 3       361207.971589
# 4        11172.422598
#             ...
# 1333     83973.870526
# 1334      3635.779999
# 1335      1984.304979
# 1336      3012.201941
# 1337    634658.902932
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.274492
# 1         2224.380678
# 2        14793.393235
# 3       361210.067093
# 4        11172.777120
#             ...
# 1333     83975.071766
# 1334      3635.901052
# 1335      1984.385354
# 1336      3012.329669
# 1337    634664.596837
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.183261
# 1         2224.716676
# 2        14794.620036
# 3       361216.316671
# 4        11173.880854
#             ...
# 1333     83979.671339
# 1334      3636.304831
# 1335      1984.711956
# 1336      3012.723315
# 1337    634679.043066
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.028940
# 1         2224.695034
# 2        14794.432595
# 3       361214.769555
# 4        11173.654669
#             ...
# 1333     83978.529293
# 1334      3636.289160
# 1335      1984.690769
# 1336      3012.683248
# 1337    634674.633188
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.567451
# 1         2224.790276
# 2        14794.507717
# 3       361214.266643
# 4        11173.652925
#             ...
# 1333     83977.931207
# 1334      3636.382411
# 1335      1984.797166
# 1336      3012.727257
# 1337    634672.013427
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.093662
# 1         2224.932072
# 2        14795.203138
# 3       361218.302553
# 4        11174.310472
#             ...
# 1333     83981.089323
# 1334      3636.571433
# 1335      1984.931282
# 1336      3012.935210
# 1337    634682.930636
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.934985
# 1         2224.501452
# 2        14793.676647
# 3       361209.560731
# 4        11172.769947
#             ...
# 1333     83974.970161
# 1334      3636.006120
# 1335      1984.499033
# 1336      3012.396004
# 1337    634662.197712
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.482079
# 1         2224.758814
# 2        14794.670805
# 3       361215.525243
# 4        11173.797080
#             ...
# 1333     83979.216860
# 1334      3636.332318
# 1335      1984.736733
# 1336      3012.725514
# 1337    634676.200765
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.554223
# 1         2224.638762
# 2        14794.303829
# 3       361214.591260
# 4        11173.585370
#             ...
# 1333     83978.366494
# 1334      3636.207482
# 1335      1984.632797
# 1336      3012.631272
# 1337    634674.687782
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.744592
# 1         2224.211620
# 2        14793.067767
# 3       361208.971725
# 4        11172.486280
#             ...
# 1333     83974.558609
# 1334      3635.673088
# 1335      1984.187980
# 1336      3012.186042
# 1337    634662.693324
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.521801
# 1         2224.826510
# 2        14794.544020
# 3       361213.877623
# 4        11173.613352
#             ...
# 1333     83977.599510
# 1334      3636.395115
# 1335      1984.821160
# 1336      3012.691305
# 1337    634670.432998
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.221992
# 1         2224.618628
# 2        14794.221993
# 3       361213.697804
# 4        11173.439329
#             ...
# 1333     83977.833797
# 1334      3636.162512
# 1335      1984.604204
# 1336      3012.584402
# 1337    634672.546973
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.708220
# 1         2224.250818
# 2        14793.045449
# 3       361207.633603
# 4        11172.321578
#             ...
# 1333     83973.646886
# 1334      3635.714492
# 1335      1984.243689
# 1336      3012.163032
# 1337    634658.875222
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.862564
# 1         2224.572247
# 2        14794.069324
# 3       361212.751402
# 4        11173.267515
#             ...
# 1333     83977.195491
# 1334      3636.114040
# 1335      1984.562726
# 1336      3012.541825
# 1337    634670.398243
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.186045
# 1         2225.087633
# 2        14795.587071
# 3       361219.370259
# 4        11174.566967
#             ...
# 1333     83981.789933
# 1334      3636.729377
# 1335      1985.072804
# 1336      3013.041885
# 1337    634683.873255
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.761486
# 1         2225.132817
# 2        14795.848345
# 3       361220.759881
# 4        11174.780320
#             ...
# 1333     83982.944514
# 1334      3636.772219
# 1335      1985.101521
# 1336      3013.114761
# 1337    634687.727851
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.930657
# 1         2224.746845
# 2        14794.702979
# 3       361216.786031
# 4        11173.967319
#             ...
# 1333     83979.954714
# 1334      3636.363028
# 1335      1984.745891
# 1336      3012.792120
# 1337    634680.517473
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.758993
# 1         2224.098460
# 2        14792.691704
# 3       361207.509501
# 4        11172.199452
#             ...
# 1333     83973.397685
# 1334      3635.533318
# 1335      1984.087350
# 1336      3012.070159
# 1337    634659.908630
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.992112
# 1         2224.606734
# 2        14794.138597
# 3       361213.490588
# 4        11173.410242
#             ...
# 1333     83977.554539
# 1334      3636.154446
# 1335      1984.597718
# 1336      3012.567551
# 1337    634671.619445
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.357242
# 1         2225.236196
# 2        14796.076977
# 3       361220.999108
# 4        11174.885963
#             ...
# 1333     83983.149813
# 1334      3636.904756
# 1335      1985.219653
# 1336      3013.182842
# 1337    634687.655658
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.686571
# 1         2225.159080
# 2        14795.710613
# 3       361219.350789
# 4        11174.613023
#             ...
# 1333     83981.732829
# 1334      3636.809652
# 1335      1985.146671
# 1336      3013.092019
# 1337    634683.250583
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.664307
# 1         2224.662939
# 2        14794.498780
# 3       361215.359564
# 4        11173.700306
#             ...
# 1333     83979.181364
# 1334      3636.208711
# 1335      1984.628974
# 1336      3012.653802
# 1337    634676.570590
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.097855
# 1         2224.921260
# 2        14795.108947
# 3       361218.154270
# 4        11174.295010
#             ...
# 1333     83980.803646
# 1334      3636.563901
# 1335      1984.913981
# 1336      3012.938946
# 1337    634681.937884
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.891591
# 1         2224.963778
# 2        14794.967838
# 3       361215.320186
# 4        11173.920644
#             ...
# 1333     83978.792124
# 1334      3636.587598
# 1335      1984.969361
# 1336      3012.846423
# 1337    634673.581375
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.904315
# 1         2224.176238
# 2        14793.003007
# 3       361209.421329
# 4        11172.541759
#             ...
# 1333     83974.827179
# 1334      3635.660766
# 1335      1984.173355
# 1336      3012.198539
# 1337    634664.860115
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.569482
# 1         2224.303506
# 2        14793.340960
# 3       361209.513818
# 4        11172.619762
#             ...
# 1333     83975.103440
# 1334      3635.782632
# 1335      1984.279011
# 1336      3012.277268
# 1337    634663.669938
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.420835
# 1         2224.564119
# 2        14793.797963
# 3       361210.622558
# 4        11172.977753
#             ...
# 1333     83975.447969
# 1334      3636.103541
# 1335      1984.573563
# 1336      3012.449911
# 1337    634664.272405
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.055326
# 1         2224.690841
# 2        14794.589134
# 3       361215.909883
# 4        11173.795438
#             ...
# 1333     83979.531344
# 1334      3636.241752
# 1335      1984.655037
# 1336      3012.689308
# 1337    634678.019542
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.453115
# 1         2224.630187
# 2        14794.245100
# 3       361213.432524
# 4        11173.403446
#             ...
# 1333     83977.708032
# 1334      3636.184246
# 1335      1984.622095
# 1336      3012.603143
# 1337    634672.072283
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.704619
# 1         2224.899732
# 2        14794.670847
# 3       361212.978717
# 4        11173.519434
#             ...
# 1333     83977.118176
# 1334      3636.465487
# 1335      1984.894835
# 1336      3012.715672
# 1337    634667.337423
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.294748
# 1         2224.374068
# 2        14793.665319
# 3       361212.078286
# 4        11173.027299
#             ...
# 1333     83976.828075
# 1334      3635.860332
# 1335      1984.345759
# 1336      3012.385014
# 1337    634670.315001
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.880253
# 1         2224.800867
# 2        14794.808400
# 3       361216.164407
# 4        11173.921110
#             ...
# 1333     83979.698029
# 1334      3636.396372
# 1335      1984.780708
# 1336      3012.771968
# 1337    634677.653224
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.161444
# 1         2224.925443
# 2        14795.208424
# 3       361218.524064
# 4        11174.332564
#             ...
# 1333     83981.225314
# 1334      3636.551761
# 1335      1984.913938
# 1336      3012.943854
# 1337    634683.447471
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.850875
# 1         2224.655501
# 2        14794.419756
# 3       361215.550343
# 4        11173.724155
#             ...
# 1333     83979.040840
# 1334      3636.215138
# 1335      1984.632957
# 1336      3012.668279
# 1337    634677.349701
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.443009
# 1         2225.121634
# 2        14795.551617
# 3       361218.870120
# 4        11174.528627
#             ...
# 1333     83981.253373
# 1334      3636.775962
# 1335      1985.112257
# 1336      3013.046895
# 1337    634682.165139
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.847415
# 1         2224.440964
# 2        14793.670010
# 3       361211.336292
# 4        11172.988055
#             ...
# 1333     83976.134920
# 1334      3635.959713
# 1335      1984.439043
# 1336      3012.420234
# 1337    634667.628679
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.571481
# 1         2225.126207
# 2        14795.704911
# 3       361220.261091
# 4        11174.726907
#             ...
# 1333     83982.340882
# 1334      3636.793887
# 1335      1985.118330
# 1336      3013.103955
# 1337    634685.877311
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.156176
# 1         2224.341873
# 2        14793.567896
# 3       361212.383085
# 4        11173.069141
#             ...
# 1333     83976.898610
# 1334      3635.860296
# 1335      1984.330111
# 1336      3012.376879
# 1337    634671.269359
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.008862
# 1         2224.798804
# 2        14794.660678
# 3       361215.446749
# 4        11173.818452
#             ...
# 1333     83978.893920
# 1334      3636.415518
# 1335      1984.807826
# 1336      3012.771435
# 1337    634676.090658
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.966786
# 1         2224.322354
# 2        14793.609200
# 3       361212.206008
# 4        11173.008783
#             ...
# 1333     83977.034943
# 1334      3635.786206
# 1335      1984.277423
# 1336      3012.338577
# 1337    634671.217837
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213078.159331
# 1         2225.163276
# 2        14795.791762
# 3       361220.471182
# 4        11174.781918
# ...
# 1         2225.097849
# 2        14795.788078
# 3       361220.622055
# 4        11174.749982
#             ...
# 1333     83982.968165
# 1334      3636.750766
# 1335      1985.074948
# 1336      3013.080477
# 1337    634687.878367
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.419247
# 1         2224.760670
# 2        14794.635626
# 3       361214.985116
# 4        11173.712169
#             ...
# 1333     83978.831988
# 1334      3636.343468
# 1335      1984.753018
# 1336      3012.724608
# 1337    634675.069238
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.884388
# 1         2225.044314
# 2        14795.516987
# 3       361220.136099
# 4        11174.651089
#             ...
# 1333     83982.174895
# 1334      3636.688703
# 1335      1985.022471
# 1336      3013.034460
# 1337    634685.891737
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.400440
# 1         2224.726784
# 2        14794.732416
# 3       361217.027457
# 4        11173.978498
#             ...
# 1333     83980.244710
# 1334      3636.292116
# 1335      1984.686104
# 1336      3012.750340
# 1337    634680.286785
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.893981
# 1         2224.795578
# 2        14794.768394
# 3       361216.471095
# 4        11173.955251
#             ...
# 1333     83979.711284
# 1334      3636.391338
# 1335      1984.788099
# 1336      3012.799249
# 1337    634678.619992
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.395856
# 1         2224.570361
# 2        14794.316307
# 3       361216.097171
# 4        11173.742040
#             ...
# 1333     83979.487094
# 1334      3636.132424
# 1335      1984.546164
# 1336      3012.632883
# 1337    634679.791079
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.380711
# 1         2224.528766
# 2        14793.891578
# 3       361211.606318
# 4        11173.078477
#             ...
# 1333     83976.395643
# 1334      3636.053786
# 1335      1984.517020
# 1336      3012.459483
# 1337    634667.691630
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.129454
# 1         2224.864565
# 2        14794.704230
# 3       361214.707820
# 4        11173.761215
#             ...
# 1333     83978.288157
# 1334      3636.474177
# 1335      1984.870994
# 1336      3012.775839
# 1337    634672.967738
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.816452
# 1         2224.812625
# 2        14794.977295
# 3       361217.337568
# 4        11174.074916
#             ...
# 1333     83980.642264
# 1334      3636.385006
# 1335      1984.778933
# 1336      3012.799746
# 1337    634680.846702
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.679365
# 1         2224.241850
# 2        14792.930939
# 3       361207.274058
# 4        11172.278303
#             ...
# 1333     83973.180873
# 1334      3635.695231
# 1335      1984.223634
# 1336      3012.151052
# 1337    634657.078785
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.243669
# 1         2224.774127
# 2        14794.348497
# 3       361212.693895
# 4        11173.413124
#             ...
# 1333     83976.789014
# 1334      3636.340027
# 1335      1984.780538
# 1336      3012.650284
# 1337    634667.831630
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.323408
# 1         2224.890966
# 2        14794.953919
# 3       361216.440677
# 4        11174.012156
#             ...
# 1333     83979.660212
# 1334      3636.483111
# 1335      1984.871281
# 1336      3012.824067
# 1337    634677.168796
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.211238
# 1         2224.472923
# 2        14793.981748
# 3       361213.846763
# 4        11173.359531
#             ...
# 1333     83978.047909
# 1334      3636.009701
# 1335      1984.456676
# 1336      3012.495903
# 1337    634674.343303
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.872009
# 1         2224.717229
# 2        14794.320379
# 3       361212.490645
# 4        11173.333778
#             ...
# 1333     83976.974677
# 1334      3636.275226
# 1335      1984.706724
# 1336      3012.619410
# 1337    634668.144420
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.053337
# 1         2224.659494
# 2        14794.561813
# 3       361217.080148
# 4        11173.951106
#             ...
# 1333     83980.181686
# 1334      3636.245791
# 1335      1984.635143
# 1336      3012.730990
# 1337    634681.274802
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.881269
# 1         2224.554920
# 2        14794.193149
# 3       361214.725115
# 4        11173.537525
#             ...
# 1333     83978.589200
# 1334      3636.098421
# 1335      1984.533859
# 1336      3012.577551
# 1337    634675.906172
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.708622
# 1         2224.999608
# 2        14795.499519
# 3       361219.477342
# 4        11174.511302
#             ...
# 1333     83982.123909
# 1334      3636.625739
# 1335      1984.975134
# 1336      3013.000995
# 1337    634685.721312
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.094342
# 1         2224.754526
# 2        14794.285142
# 3       361212.969933
# 4        11173.450170
#             ...
# 1333     83976.849862
# 1334      3636.329543
# 1335      1984.756662
# 1336      3012.653806
# 1337    634668.154802
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.187026
# 1         2224.159580
# 2        14792.901700
# 3       361207.711125
# 4        11172.263680
#             ...
# 1333     83973.785510
# 1334      3635.585187
# 1335      1984.135812
# 1336      3012.104478
# 1337    634660.145159
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.353252
# 1         2224.512206
# 2        14793.940971
# 3       361212.499178
# 4        11173.194162
#             ...
# 1333     83977.070178
# 1334      3636.048346
# 1335      1984.499431
# 1336      3012.494015
# 1337    634670.243222
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.890930
# 1         2225.122436
# 2        14795.749492
# 3       361220.975852
# 4        11174.817716
#             ...
# 1333     83982.812318
# 1334      3636.800454
# 1335      1985.120080
# 1336      3013.141469
# 1337    634688.587449
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.717191
# 1         2224.332533
# 2        14793.342727
# 3       361208.947937
# 4        11172.571472
#             ...
# 1333     83974.718638
# 1334      3635.827316
# 1335      1984.322811
# 1336      3012.269992
# 1337    634662.151946
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.860795
# 1         2224.253279
# 2        14793.194814
# 3       361208.726169
# 4        11172.463369
#             ...
# 1333     83974.566853
# 1334      3635.691265
# 1335      1984.219509
# 1336      3012.186303
# 1337    634661.971684
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.944306
# 1         2224.783420
# 2        14794.388460
# 3       361212.575535
# 4        11173.399989
#             ...
# 1333     83976.817413
# 1334      3636.341682
# 1335      1984.784614
# 1336      3012.627318
# 1337    634667.398847
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.592121
# 1         2224.514658
# 2        14794.082845
# 3       361213.681080
# 4        11173.355460
#             ...
# 1333     83978.014568
# 1334      3636.035879
# 1335      1984.473128
# 1336      3012.529168
# 1337    634673.225825
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.182736
# 1         2224.661176
# 2        14794.070704
# 3       361211.883956
# 4        11173.225079
#             ...
# 1333     83976.269376
# 1334      3636.225314
# 1335      1984.668083
# 1336      3012.550706
# 1337    634666.489860
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.212776
# 1         2224.234256
# 2        14793.309943
# 3       361210.700623
# 4        11172.747535
#             ...
# 1333     83975.994930
# 1334      3635.715765
# 1335      1984.209545
# 1336      3012.249060
# 1337    634667.860805
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.702193
# 1         2225.002149
# 2        14795.372757
# 3       361218.650839
# 4        11174.409954
#             ...
# 1333     83981.327255
# 1334      3636.633472
# 1335      1984.974169
# 1336      3012.984132
# 1337    634682.363432
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.680380
# 1         2224.649745
# 2        14794.431465
# 3       361215.686849
# 4        11173.741197
#             ...
# 1333     83979.177140
# 1334      3636.203050
# 1335      1984.628205
# 1336      3012.666569
# 1337    634677.440050
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.767391
# 1         2224.648445
# 2        14794.374098
# 3       361215.246750
# 4        11173.684844
#             ...
# 1333     83978.830328
# 1334      3636.221169
# 1335      1984.634022
# 1336      3012.661473
# 1337    634676.487101
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.953686
# 1         2224.405262
# 2        14793.935950
# 3       361213.761697
# 4        11173.290944
#             ...
# 1333     83978.297544
# 1334      3635.935751
# 1335      1984.375880
# 1336      3012.489228
# 1337    634674.982877
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.155127
# 1         2224.958704
# 2        14795.154136
# 3       361216.897397
# 4        11174.135350
#             ...
# 1333     83980.145153
# 1334      3636.592871
# 1335      1984.954942
# 1336      3012.897175
# 1337    634678.551422
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.118544
# 1         2224.811830
# 2        14795.026813
# 3       361218.565412
# 4        11174.249636
#             ...
# 1333     83981.338708
# 1334      3636.401754
# 1335      1984.772294
# 1336      3012.841956
# 1337    634684.190600
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.350181
# 1         2225.101786
# 2        14795.578037
# 3       361219.432834
# 4        11174.592419
#             ...
# 1333     83981.709528
# 1334      3636.754236
# 1335      1985.084697
# 1336      3013.045400
# 1337    634683.877566
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.652647
# 1         2224.754476
# 2        14794.841663
# 3       361217.503402
# 4        11174.077767
#             ...
# 1333     83980.701685
# 1334      3636.348657
# 1335      1984.729306
# 1336      3012.784728
# 1337    634681.847991
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.646236
# 1         2224.377837
# 2        14793.274697
# 3       361208.504819
# 4        11172.544853
#             ...
# 1333     83973.968698
# 1334      3635.845862
# 1335      1984.365493
# 1336      3012.245319
# 1337    634659.514478
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.236916
# 1         2224.973746
# 2        14795.296112
# 3       361217.642743
# 4        11174.232936
#             ...
# 1333     83980.804995
# 1334      3636.586667
# 1335      1984.949415
# 1336      3012.919501
# 1337    634680.691895
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213069.995864
# 1         2224.241655
# 2        14793.184412
# 3       361210.168526
# 4        11172.670873
#             ...
# 1333     83975.248210
# 1334      3635.713618
# 1335      1984.227373
# 1336      3012.236974
# 1337    634665.840934
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.740916
# 1         2224.930886
# 2        14794.977843
# 3       361215.524917
# 4        11173.924998
#             ...
# 1333     83979.152885
# 1334      3636.558031
# 1335      1984.935141
# 1336      3012.856110
# 1337    634674.739767
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.040157
# 1         2224.361848
# 2        14793.646332
# 3       361211.712487
# 4        11172.975084
#             ...
# 1333     83976.715864
# 1334      3635.856798
# 1335      1984.326311
# 1336      3012.352928
# 1337    634669.163151
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.216031
# 1         2224.632724
# 2        14794.084236
# 3       361212.672493
# 4        11173.314334
#             ...
# 1333     83976.849583
# 1334      3636.198215
# 1335      1984.645746
# 1336      3012.576634
# 1337    634669.380798
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213076.839376
# 1         2225.051924
# 2        14795.525385
# 3       361218.688822
# 4        11174.441263
#             ...
# 1333     83981.540188
# 1334      3636.685893
# 1335      1985.026294
# 1336      3013.007045
# 1337    634682.632047
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213073.581343
# 1         2224.617331
# 2        14794.189231
# 3       361213.834342
# 4        11173.467272
#             ...
# 1333     83977.809677
# 1334      3636.184250
# 1335      1984.612416
# 1336      3012.615205
# 1337    634672.956313
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213068.049706
# 1         2224.018856
# 2        14792.364630
# 3       361205.666086
# 4        11171.891229
#             ...
# 1333     83972.026627
# 1334      3635.421412
# 1335      1984.002576
# 1336      3011.962676
# 1337    634655.019642
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.211174
# 1         2224.445867
# 2        14794.090126
# 3       361214.309987
# 4        11173.385798
#             ...
# 1333     83978.765724
# 1334      3635.964949
# 1335      1984.412017
# 1336      3012.496305
# 1337    634676.833202
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.087177
# 1         2224.439259
# 2        14794.076674
# 3       361215.015937
# 4        11173.493512
#             ...
# 1333     83979.086394
# 1334      3635.963610
# 1335      1984.411526
# 1336      3012.514543
# 1337    634678.086902
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213072.580435
# 1         2224.583520
# 2        14793.870257
# 3       361211.281660
# 4        11173.069188
#             ...
# 1333     83975.779200
# 1334      3636.098849
# 1335      1984.575765
# 1336      3012.488552
# 1337    634665.312635
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.537049
# 1         2225.118951
# 2        14795.759243
# 3       361220.155245
# 4        11174.707129
#             ...
# 1333     83982.555844
# 1334      3636.789668
# 1335      1985.108112
# 1336      3013.097315
# 1337    634686.144148
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213075.463301
# 1         2224.860192
# 2        14794.868264
# 3       361216.473772
# 4        11174.019597
#             ...
# 1333     83979.670538
# 1334      3636.486513
# 1335      1984.858848
# 1336      3012.826134
# 1337    634677.902655
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213070.966855
# 1         2224.417621
# 2        14793.431098
# 3       361208.873935
# 4        11172.616268
#             ...
# 1333     83974.382911
# 1334      3635.911262
# 1335      1984.408830
# 1336      3012.301881
# 1337    634660.358373
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213074.234425
# 1         2224.699190
# 2        14794.566794
# 3       361216.122240
# 4        11173.846772
#             ...
# 1333     83979.546416
# 1334      3636.295509
# 1335      1984.684292
# 1336      3012.730806
# 1337    634678.489292
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213071.998165
# 1         2224.470611
# 2        14793.609256
# 3       361210.765542
# 4        11172.943697
#             ...
# 1333     83975.512878
# 1334      3636.006048
# 1335      1984.473884
# 1336      3012.419350
# 1337    634665.137492
# Name: charges, Length: 1338, dtype: float64
# Epoch 0: MSE = 0       213077.938153
# 1         2225.154189
# 2        14795.888038
# 3       361221.164950
# 4        11174.862956
#             ...
# 1333     83983.156526
# 1334      3636.837729
# 1335      1985.148409
# 1336      3013.159478
# 1337    634688.845326
# Name: charges, Length: 1338, dtype: float64
# {'R2': 0.12879027676330512, 'RMSE': 11299.092133405387, 'MAE': 9009.256427732278}

# %%
linreg_a = LinearRegression()

linreg_a.fit(X_encoded, y)

y_predict_a = linreg_a.predict(X_encoded)
evaluation_metrics_a = evaluate_regression(y, y_predict_a)
print(evaluation_metrics_a)

intercept_a = linreg_a.intercept_
coefficients_a = linreg_a.coef_
# Out:
# {'R2': 0.7509130345985207, 'RMSE': 6041.6796511744515, 'MAE': 4170.886894163588}

# %%
iter_space = list(range(10**3))

num_columns = 10
num_coeficients = 8

fig, axes = plt.subplots(num_columns, 1, figsize=(12, 4 * num_columns))
plt.subplots_adjust(hspace=0.3)

axes[0].plot(iter_space, mae, "-", label="MAE", color="green")
axes[0].set_title("Error Cuadrático Medio (MAE)")
axes[0].axhline(evaluation_metrics_a["RMSE"] ** 2, label="MAE de SkLearn", color="black")
axes[0].legend()
axes[0].grid()

axes[1].plot(iter_space, intercept_m, "-", label="Intercepto", color="blue")
axes[1].axhline(intercept_a, label="Intercepto de SkLearn", color="black")
axes[1].set_title("Intercepto")
axes[1].legend()
axes[1].grid()

for i in range(num_coeficients):
    subplot_index = i + 2
    coef_iter_values = [coefficients_m[j][i] for j in range(10**3)]
    axes[subplot_index].plot(iter_space, coef_iter_values, "-", label=f"Coeficiente x{i}")
    axes[subplot_index].axhline(coefficients_a[i], label=f"Coeficiente x{i} de SkLearn", color="black")
    axes[subplot_index].set_title(f"Coeficiente x{i}")
    axes[subplot_index].legend()
    axes[subplot_index].grid()

axes[-1].set_xlabel("Iteraciones")

plt.show()
